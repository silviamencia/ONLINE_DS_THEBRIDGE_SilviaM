# %% [markdown]
# # Manipulación básica de datos

# %% [markdown]
# Cambiamos el directorio de trabajo a la carpeta en la que se encuentran nuestros datos.

# %%
import os
os.chdir(r"/content/sample_data")

# %% [markdown]
# Importamos las librerías que vamos a utilizar para tratar los datos.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Carga de datos.

# %% [markdown]
# El método `read_csv()` nos sirve para abrir archivos de datos en los que el dato se encuentra en archivos de texto plano.

# %%
pd.read_csv("consumoelectricov1.csv")
# Obtenemos el error:
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 53: invalid continuation byte
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-19-b2ee42aa8bd3> in <cell line: 1>()
# ----> 1 pd.read_csv("consumoelectricov1.csv")
#       2 # Obtenemos el error:
#       3 # UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 53: invalid continuation byte
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1896
#    1897         try:
# -> 1898             return mapping[engine](f, **self.options)
#    1899         except Exception:
#    1900             if self.handles is not None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      91             # Fail here loudly instead of in cython after reading
#      92             import_optional_dependency("pyarrow")
# ---> 93         self._reader = parsers.TextReader(src, **kwds)
#      94
#      95         self.unnamed_cols = self._reader.unnamed_cols
#
# parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 53: invalid continuation byte

# %% [markdown]
# Al ser texto plano, puede estar codificado para contener caracteres especiales como la ñ y las letras con tilde como en este caso.

# %%
pd.read_csv("consumoelectricov1.csv", encoding="latin-1")
# Obtenemos el error:
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 5, saw 9

# %% [markdown]
# Los csv (comma separated values) usan las comas para separar los datos de cada fila en columnas y los saltos de línea para separar las filas. Sin embargo no es raro encontrarnos con 'csv's que usen otros caracteres separadores.

# %%
pd.read_csv("consumoelectricov1.csv", sep=";", encoding="latin-1")
# Out:
#     Indicadores municipales de sostenibilidad: Consumo eléctrico anual del municipio (Kwh./habitante)  \
# 0                                                  NaN
# 1                                     Resumen de datos
# 2                                              Entidad
# 3                                          Araba/Álava
# 4                                              Bizkaia
# ..                                                 ...
# 279                                              48915
# 280                                              20028
# 281                                               1063
# 282                                              20081
# 283                                              20080
#
#           Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                NaN        NaN        NaN        NaN        NaN        NaN
# 1                NaN        NaN        NaN        NaN        NaN        NaN
# 2                NaN       2015       2014       2013       2012       2011
# 3                NaN   7.562,88   7.595,83   7.578,43   7.939,13   8.216,86
# 4                NaN   6.581,07   6.405,24   6.073,57   6.000,82   6.678,99
# ..               ...        ...        ...        ...        ...        ...
# 279  Ziortza-Bolibar   2.088,98   1.967,21   2.155,81   2.258,48   1.611,92
# 280         Zizurkil  14.627,46  13.818,31  13.382,69  17.124,82  17.584,41
# 281             Zuia   3.475,49   3.452,86   3.585,49   3.526,35   3.733,28
# 282           Zumaia   8.866,33   8.520,32   8.485,99   8.271,42   8.032,16
# 283        Zumarraga  50.697,97  49.091,91  47.509,10  49.579,07  53.585,17
#
#     Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 0          NaN        NaN        NaN         NaN         NaN         NaN
# 1          NaN        NaN        NaN         NaN         NaN         NaN
# 2         2010       2009       2008        2007        2006        2005
# 3     7.978,62   7.477,28   9.211,09           0           0           0
# 4     6.902,48   6.343,39   7.607,47           0           0           0
# ..         ...        ...        ...         ...         ...         ...
# 279   1.765,80   1.795,82   1.758,68    1.259,54    1.315,58    2.668,96
# 280  18.497,73  17.724,03  16.189,97    5.803,96    5.800,26    5.373,82
# 281   3.897,58   3.880,25   4.097,61    4.205,70    4.150,84    4.064,04
# 282   7.900,01   7.374,67   9.136,98    8.739,55    9.655,69    9.093,28
# 283  56.577,73  45.270,76  45.000,57   53.834,12   59.396,16   52.384,14
#
#     Unnamed: 13 Unnamed: 14 Unnamed: 15
# 0           NaN         NaN         NaN
# 1           NaN         NaN         NaN
# 2          2004        2003        2002
# 3             0         NaN           0
# 4             0         NaN           0
# ..          ...         ...         ...
# 279    4.714,38    4.608,56    4.248,04
# 280    5.185,71    5.159,19    5.087,84
# 281    4.112,30    3.967,08    3.855,15
# 282    8.743,57    8.313,31    7.804,46
# 283   54.877,85   62.683,29   61.094,00
#
# [284 rows x 16 columns]

# %% [markdown]
# En este caso, dada la distribución de los datos en el csv debemos usar skiprows ya que las 33 primeras filas no son información útil.

# %%
consumo=pd.read_csv("consumoelectricov1.csv", sep=";", skiprows=33, encoding='latin-1')

# %% [markdown]
# Por fin, podemos ver los datos.
#
# `head()` y `tail()` nos devuelven una muestra del principio y final de nuestra tabla.

# %%
consumo.head(8)
# Out:
#    Codigo municipio                          Municipio        2015  \
# 0             48001                            Abadiño   19.112,86
# 1             20001                       Abaltzisketa    1.775,42
# 2             48002  Abanto y Ciérvana-Abanto Zierbena    6.626,98
# 3             20002                              Aduna   31.356,73
# 4             20016                                Aia    6.830,56
# 5             20003                       Aizarnazabal  101.231,41
# 6             48911                            Ajangiz   60.798,19
# 7             20004                           Albiztur    4.403,23
#
#          2014        2013       2012        2011        2010        2009  \
# 0   18.218,65   17.007,75  17.492,94   19.038,20   17.434,98   14.902,98
# 1    1.976,36    2.334,03   2.674,67    2.093,31    2.324,47    2.193,65
# 2    6.766,62    6.226,93   5.921,76    5.488,18    5.228,24    4.835,82
# 3   30.456,01   31.958,31  31.283,90   30.289,75   30.512,82   29.608,55
# 4    7.063,86    7.381,57   7.450,48    7.597,10    7.508,26    7.420,62
# 5  106.143,00  111.945,62  95.357,66  120.703,86  127.260,11  107.453,11
# 6   56.880,09   57.792,04  58.705,44   61.449,32   58.778,30   49.522,39
# 7    3.880,91    8.297,03  10.027,32   10.499,80   10.423,24   10.556,58
#
#          2008        2007        2006        2005        2004        2003  \
# 0   19.500,46   20.116,32   20.306,64   19.993,84   20.328,15   19.292,68
# 1    2.301,17    2.612,19    2.015,60    2.270,07    2.186,96    2.311,37
# 2    6.010,92    6.246,63    5.714,46    5.356,14    5.042,83    4.462,76
# 3   37.226,58   37.006,68   37.842,85   36.934,28   41.027,15   36.532,05
# 4    9.284,10   10.350,79   10.289,29   10.580,32   10.380,22    9.616,06
# 5  136.313,18  140.479,44  139.652,55  154.155,67  159.191,20  156.092,21
# 6   54.603,87    3.348,66    3.120,09    3.138,43    3.308,67    3.198,33
# 7   10.906,02   10.611,05   10.657,70   10.318,57    8.505,80    8.789,97
#
#          2002
# 0   18.073,94
# 1    2.289,61
# 2    4.227,28
# 3   37.132,90
# 4    8.897,38
# 5  166.830,79
# 6    2.953,02
# 7    8.262,13

# %%
consumo.tail(7)
# Out:
#      Codigo municipio        Municipio       2015       2014       2013  \
# 244             48913         Zierbena  45.732,44  34.891,95  30.812,56
# 245              1018         Zigoitia  13.224,36  13.648,62  15.038,86
# 246             48915  Ziortza-Bolibar   2.088,98   1.967,21   2.155,81
# 247             20028         Zizurkil  14.627,46  13.818,31  13.382,69
# 248              1063             Zuia   3.475,49   3.452,86   3.585,49
# 249             20081           Zumaia   8.866,33   8.520,32   8.485,99
# 250             20080        Zumarraga  50.697,97  49.091,91  47.509,10
#
#           2012       2011       2010       2009       2008       2007  \
# 244  36.686,19  39.654,72  47.372,97  49.162,84  55.604,65  47.820,02
# 245  15.556,49  17.391,52  18.024,80  18.739,66  21.107,03  21.575,98
# 246   2.258,48   1.611,92   1.765,80   1.795,82   1.758,68   1.259,54
# 247  17.124,82  17.584,41  18.497,73  17.724,03  16.189,97   5.803,96
# 248   3.526,35   3.733,28   3.897,58   3.880,25   4.097,61   4.205,70
# 249   8.271,42   8.032,16   7.900,01   7.374,67   9.136,98   8.739,55
# 250  49.579,07  53.585,17  56.577,73  45.270,76  45.000,57  53.834,12
#
#           2006       2005       2004       2003       2002
# 244  49.610,42  40.692,27  42.470,29  20.059,96  16.554,04
# 245  23.615,45  24.836,76  25.443,08  25.999,79  25.330,42
# 246   1.315,58   2.668,96   4.714,38   4.608,56   4.248,04
# 247   5.800,26   5.373,82   5.185,71   5.159,19   5.087,84
# 248   4.150,84   4.064,04   4.112,30   3.967,08   3.855,15
# 249   9.655,69   9.093,28   8.743,57   8.313,31   7.804,46
# 250  59.396,16  52.384,14  54.877,85  62.683,29  61.094,00

# %% [markdown]
# ### Cómo se seleccionan datos en un DataFrame.

# %% [markdown]
# Mediante `iloc` podemos seleccionar las celdas mediante índices numéricos. Entre los corchetes indicaremos primero las filas y después las columnas que queramos seleccionar.

# %% [markdown]
# Los índices pueden ser rangos.

# %%
consumo.iloc[1:5,1:8]
# Out:
#                            Municipio       2015       2014       2013  \
# 1                       Abaltzisketa   1.775,42   1.976,36   2.334,03
# 2  Abanto y Ciérvana-Abanto Zierbena   6.626,98   6.766,62   6.226,93
# 3                              Aduna  31.356,73  30.456,01  31.958,31
# 4                                Aia   6.830,56   7.063,86   7.381,57
#
#         2012       2011       2010
# 1   2.674,67   2.093,31   2.324,47
# 2   5.921,76   5.488,18   5.228,24
# 3  31.283,90  30.289,75  30.512,82
# 4   7.450,48   7.597,10   7.508,26

# %% [markdown]
# Los rangos son como los que hemos usado en las listas. Con inicio, final y, opcionalmente, salto.

# %%
consumo.iloc[0:10:3,0:10:2]
# Out:
#    Codigo municipio       2015       2013       2011       2009
# 0             48001  19.112,86  17.007,75  19.038,20  14.902,98
# 3             20002  31.356,73  31.958,31  30.289,75  29.608,55
# 6             48911  60.798,19  57.792,04  61.449,32  49.522,39
# 9              1001   6.844,81   7.714,15   8.188,89   8.765,79

# %% [markdown]
# También podemos dar una lista de posiciones, o pedir todas las posiciones dejando los ":" sólos

# %%
consumo.iloc[:,[3,6,8]]
# Out:
#           2014       2011       2009
# 0    18.218,65  19.038,20  14.902,98
# 1     1.976,36   2.093,31   2.193,65
# 2     6.766,62   5.488,18   4.835,82
# 3    30.456,01  30.289,75  29.608,55
# 4     7.063,86   7.597,10   7.420,62
# ..         ...        ...        ...
# 246   1.967,21   1.611,92   1.795,82
# 247  13.818,31  17.584,41  17.724,03
# 248   3.452,86   3.733,28   3.880,25
# 249   8.520,32   8.032,16   7.374,67
# 250  49.091,91  53.585,17  45.270,76
#
# [251 rows x 3 columns]

# %% [markdown]
# Mediante `loc` podemos seleccionar las celdas a partir de los nombres de las columnas y del índice

# %%
print(consumo.columns)
# Out:
# Index(['Codigo municipio', 'Municipio', '2015', '2014', '2013', '2012', '2011',
#        '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002'],
#       dtype='object')

# %%
print(consumo.index)
# Out:
# RangeIndex(start=0, stop=251, step=1)

# %% [markdown]
# Como en este caso el `index` (los nombres de las filas) son números consecutivos, también puedo usar números en el selector de filas.

# %%
consumo.loc[0:30:2,'2013':'2002']
# Out:
#          2013       2012       2011       2010       2009       2008  \
# 0   17.007,75  17.492,94  19.038,20  17.434,98  14.902,98  19.500,46
# 2    6.226,93   5.921,76   5.488,18   5.228,24   4.835,82   6.010,92
# 4    7.381,57   7.450,48   7.597,10   7.508,26   7.420,62   9.284,10
# 6   57.792,04  58.705,44  61.449,32  58.778,30  49.522,39  54.603,87
# 8   10.779,61   9.981,60  10.795,46  10.795,16   9.844,96  10.957,96
# 10   1.790,46   1.840,93   2.257,17   2.414,52   2.505,13   2.760,22
# 12   1.871,21   2.244,02   2.153,93   2.308,54   1.912,57   2.545,16
# 14  84.620,30  85.430,87  79.463,92  78.681,30  76.252,74  72.733,49
# 16   5.681,72   5.925,53   6.079,18   5.813,37   6.088,27   5.999,83
# 18   6.296,04   6.142,61   5.567,98   5.610,61   5.502,34   6.132,15
# 20   8.857,21   9.841,92   8.916,69   8.356,85   7.388,65   8.921,58
# 22   3.182,53   3.751,03   3.833,31   4.028,26   4.235,39   5.731,23
# 24   2.979,69   3.005,31   3.487,49   3.278,52   3.179,70   2.747,58
# 26   5.429,09   5.358,68   5.009,54   5.157,49   4.823,82   5.614,01
# 28   9.568,78  11.338,96  11.324,11  13.409,53  13.792,57  16.470,30
# 30   9.818,72  10.384,75  10.184,09  10.316,04   9.724,56  10.657,48
#
#          2007       2006       2005       2004       2003       2002
# 0   20.116,32  20.306,64  19.993,84  20.328,15  19.292,68  18.073,94
# 2    6.246,63   5.714,46   5.356,14   5.042,83   4.462,76   4.227,28
# 4   10.350,79  10.289,29  10.580,32  10.380,22   9.616,06   8.897,38
# 6    3.348,66   3.120,09   3.138,43   3.308,67   3.198,33   2.953,02
# 8   12.138,21  10.522,81   9.661,17   9.419,36   7.359,39   8.055,61
# 10   2.764,12   2.621,50   2.752,75   2.719,15   2.702,07   2.413,43
# 12   2.095,06   1.988,41   1.985,97   1.169,77   3.378,82   2.426,39
# 14  15.153,41  20.851,11  14.901,42  19.532,19  19.646,73  18.187,59
# 16   6.120,98   5.938,99   5.283,09   5.491,46   5.465,24   5.171,54
# 18   6.615,28   7.803,30   7.515,24   7.359,02   7.673,30   7.670,34
# 20   8.942,02   8.783,12   8.949,72   9.472,43   9.439,39   9.485,39
# 22   5.427,34   3.964,89   4.221,20   4.254,31   3.823,65   3.178,70
# 24   2.801,51   2.761,94   2.659,35   2.560,27   2.440,64   2.475,71
# 26   6.497,16   6.743,11   6.695,05   6.869,81   6.642,22   6.509,49
# 28  15.448,71  18.367,02  15.177,55  16.707,06  16.570,68  16.888,57
# 30  10.514,71   9.486,13   9.133,89   8.840,70   8.989,34   9.108,31

# %%
consumo.loc[:,['2013','2006','2002']]
# Out:
#           2013       2006       2002
# 0    17.007,75  20.306,64  18.073,94
# 1     2.334,03   2.015,60   2.289,61
# 2     6.226,93   5.714,46   4.227,28
# 3    31.958,31  37.842,85  37.132,90
# 4     7.381,57  10.289,29   8.897,38
# ..         ...        ...        ...
# 246   2.155,81   1.315,58   4.248,04
# 247  13.382,69   5.800,26   5.087,84
# 248   3.585,49   4.150,84   3.855,15
# 249   8.485,99   9.655,69   7.804,46
# 250  47.509,10  59.396,16  61.094,00
#
# [251 rows x 3 columns]

# %%
consumo.loc[1:10:2,'2013':'2002']
# Out:
#          2013       2012        2011        2010        2009        2008  \
# 1    2.334,03   2.674,67    2.093,31    2.324,47    2.193,65    2.301,17
# 3   31.958,31  31.283,90   30.289,75   30.512,82   29.608,55   37.226,58
# 5  111.945,62  95.357,66  120.703,86  127.260,11  107.453,11  136.313,18
# 7    8.297,03  10.027,32   10.499,80   10.423,24   10.556,58   10.906,02
# 9    7.714,15   8.335,28    8.188,89    8.497,26    8.765,79   10.862,13
#
#          2007        2006        2005        2004        2003        2002
# 1    2.612,19    2.015,60    2.270,07    2.186,96    2.311,37    2.289,61
# 3   37.006,68   37.842,85   36.934,28   41.027,15   36.532,05   37.132,90
# 5  140.479,44  139.652,55  154.155,67  159.191,20  156.092,21  166.830,79
# 7   10.611,05   10.657,70   10.318,57    8.505,80    8.789,97    8.262,13
# 9   10.018,43    9.552,51    9.891,08    9.432,47    9.631,26   13.465,61

# %%
consumo.loc[[11,13,23],['2013','2006','2002']]
# Out:
#          2013       2006       2002
# 11   7.465,17  10.429,98  10.877,86
# 13  37.513,26  37.659,40  34.759,82
# 23   1.668,04   3.547,12   3.471,46

# %% [markdown]
# ## Manipulación de datos.

# %% [markdown]
# Es interesante conocer la tipologia de los datos con los que vamos a trabajar

# %%
consumo.dtypes
# Out:
# Codigo municipio     int64
# Municipio           object
# 2015                object
# 2014                object
# 2013                object
# 2012                object
# 2011                object
# 2010                object
# 2009                object
# 2008                object
# 2007                object
# 2006                object
# 2005                object
# 2004                object
# 2003                object
# 2002                object
# dtype: object

# %% [markdown]
# Podemos ver como hay variables cuyo formato numérico no reconoce, cuando debería hacerlo.
#
# Si abrimos el DataFrame, observamos que el separador de decimal debería ser el punto y aqui tenemos ","
#
# También tenemos un separador de miles que es un punto.
#
# Arreglaremos esto en dos pasos:
# 1. Borrar el punto de separador de miles
# 2. Cambiar la coma por punto para el separador decimal

# %% [markdown]
# ### Manipulación de columnas/variables.

# %%
consumo["2015"]
# Out:
# 0      19.112,86
# 1       1.775,42
# 2       6.626,98
# 3      31.356,73
# 4       6.830,56
#          ...
# 246     2.088,98
# 247    14.627,46
# 248     3.475,49
# 249     8.866,33
# 250    50.697,97
# Name: 2015, Length: 251, dtype: object

# %% [markdown]
# Con las columnas de tipo `object` puedo usar directamente los métodos de los strings con el accesor `.str.`

# %%
# Así vemos tódos los métodos que nos permite usar
dir(consumo["2015"].str)
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__frozen',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_data',
#  '_doc_args',
#  '_freeze',
#  '_get_series_list',
#  '_index',
#  '_inferred_dtype',
#  '_is_categorical',
#  '_is_string',
#  '_name',
#  '_orig',
#  '_parent',
#  '_validate',
#  '_wrap_result',
#  'capitalize',
#  'casefold',
#  'cat',
#  'center',
#  'contains',
#  'count',
#  'decode',
#  'encode',
#  'endswith',
#  'extract',
#  'extractall',
#  'find',
#  'findall',
#  'fullmatch',
#  'get',
#  'get_dummies',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'islower',
#  'isnumeric',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'len',
#  'ljust',
#  'lower',
#  'lstrip',
#  'match',
#  'normalize',
#  'pad',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'repeat',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'slice',
#  'slice_replace',
#  'split',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'wrap',
#  'zfill']

# %%
consumo["2015"] = consumo["2015"].str.replace(".", "")

# %%
consumo["2015"]
# Out:
# 0      19112,86
# 1       1775,42
# 2       6626,98
# 3      31356,73
# 4       6830,56
#          ...
# 246     2088,98
# 247    14627,46
# 248     3475,49
# 249     8866,33
# 250    50697,97
# Name: 2015, Length: 251, dtype: object

# %%
consumo["2015"] = consumo["2015"].str.replace(",", ".")

# %%
consumo["2015"]
# Out:
# 0      19112.86
# 1       1775.42
# 2       6626.98
# 3      31356.73
# 4       6830.56
#          ...
# 246     2088.98
# 247    14627.46
# 248     3475.49
# 249     8866.33
# 250    50697.97
# Name: 2015, Length: 251, dtype: object

# %% [markdown]
# Ahora ya tenemos los datos en un formato que nos permite la conversión a número decimal (`float`)

# %%
consumo["2015"] = consumo["2015"].astype("float")

# %% [markdown]
# La columna 2025 ya es numérica

# %%
consumo.dtypes
# Out:
# Codigo municipio      int64
# Municipio            object
# 2015                float64
# 2014                 object
# 2013                 object
# 2012                 object
# 2011                 object
# 2010                 object
# 2009                 object
# 2008                 object
# 2007                 object
# 2006                 object
# 2005                 object
# 2004                 object
# 2003                 object
# 2002                 object
# dtype: object

# %% [markdown]
# Podemos ejecutar todas las transformaciones en una única línea de código

# %%
consumo["2014"]= consumo["2014"].str.replace(".","").str.replace(",",".").astype("float")
consumo["2014"]
# Out:
# 0      18218.65
# 1       1976.36
# 2       6766.62
# 3      30456.01
# 4       7063.86
#          ...
# 246     1967.21
# 247    13818.31
# 248     3452.86
# 249     8520.32
# 250    49091.91
# Name: 2014, Length: 251, dtype: float64

# %% [markdown]
# Como el cambio será el mismo, podemos automatizar esto para el resto de las columnas.

# %%
for columna in consumo.loc[:,'2013':'2002']:
    # Eliminamos el punto
    consumo[columna]=consumo[columna].str.replace(".","")
    # Cambiamos la coma por el punto
    consumo[columna]=consumo[columna].str.replace(",",".")
    # Convertimos la columna en numérica
    consumo[columna]=consumo[columna].astype("float")

# %%
consumo.dtypes
# Out:
# Codigo municipio      int64
# Municipio            object
# 2015                float64
# 2014                float64
# 2013                float64
# 2012                float64
# 2011                float64
# 2010                float64
# 2009                float64
# 2008                float64
# 2007                float64
# 2006                float64
# 2005                float64
# 2004                float64
# 2003                float64
# 2002                float64
# dtype: object

# %% [markdown]
# ## Creación de nuevas columnas/variables.

# %% [markdown]
# Puedo mejorar los datos con la información que tengo.
#
# El código postal del municipio me puede servir para saber a qué provincia pertenece el municipio

# %%
consumo["Codigo municipio"].dtypes
# Out:
# dtype('int64')

# %%
consumo["Codigo municipio"]
# Out:
# 0      48001
# 1      20001
# 2      48002
# 3      20002
# 4      20016
#        ...
# 246    48915
# 247    20028
# 248     1063
# 249    20081
# 250    20080
# Name: Codigo municipio, Length: 251, dtype: int64

# %% [markdown]
# Creamos una nueva variable/columna para guardar el nombre de la provincia.

# %%
consumo['provincia'] = "xxx"
consumo['provincia']
# Out:
# 0      xxx
# 1      xxx
# 2      xxx
# 3      xxx
# 4      xxx
#       ...
# 246    xxx
# 247    xxx
# 248    xxx
# 249    xxx
# 250    xxx
# Name: provincia, Length: 251, dtype: object

# %% [markdown]
# Establecemos condiciones para renombrar elementos

# %%
filtro = consumo["Codigo municipio"] < 15000

# %% [markdown]
# Una serie de datos booleanos nos puede servir para filtrar las filas del DataFrame

# %%
filtro
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 246    False
# 247    False
# 248     True
# 249    False
# 250    False
# Name: Codigo municipio, Length: 251, dtype: bool

# %% [markdown]
# Obtengo una tabla de los datos de Álava. Pero no es una tabla independiente, sino una referencia a las filas del DataFrame original. Lo que haga con los datos filtrados se reflejará en el original.

# %%
consumo[filtro]
# Out:
#      Codigo municipio                       Municipio      2015      2014  \
# 9                1001                Alegría-Dulantzi   6844.81   7461.74
# 17               1002                         Amurrio  34853.06  37074.09
# 23               1003                         Aramaio   1592.50   1607.83
# 27               1006                         Armiñón  12254.72  11627.59
# 28               1037                   Arraia-Maeztu   9771.70  10123.86
# 32               1008             Arratzua-Ubarrundia  11179.54  10977.37
# 37               1004                      Artziniega   4833.98   4819.31
# 38               1009                       Asparrena  22925.08  23079.30
# 44               1010                     Ayala/Aiara   5589.60   5680.59
# 47               1049                           Añana   4559.93   4966.99
# 53               1013                       Barrundia   2934.07   2887.89
# 55               1011           Baños de Ebro/Mañueta   2920.51   3060.10
# 61               1014                    Berantevilla  38542.53  40598.51
# 65               1016                         Bernedo   9688.66   9652.01
# 72               1017                 Campezo/Kanpezu   5417.35   4900.28
# 81               1021                 Elburgo/Burgelu   2935.27   2893.53
# 82               1022                         Elciego   7340.04   7044.66
# 87               1023                  Elvillar/Bilar   3720.36   3551.36
# 93               1046      Erriberagoitia/Ribera Alta   3732.27   3568.35
# 117              1056           Harana/Valle de Arana   2837.60   2891.20
# 128              1027                   Iruraiz-Gauna   2268.69   2086.81
# 129              1901          Iruña Oka/Iruña de Oca  12371.37  11951.75
# 136              1019                          Kripan   2814.74   2880.51
# 137              1020                       Kuartango   5067.42   4976.81
>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   consumo[filtro]["provincia"] = "Álava"

# %% [markdown]
# El cambio se ha realizado, pero aparece una advertencia ("Warning") ya que tiene que avisarme de que se está modificando el original y no una copia independiente.
#
# Por eso es mejor usar `.loc[]` ya que deja evidente que el cambio se realiza en el `DataFrame` consumo

# %%
consumo.loc[filtro, "provincia"] = "Álava"

# %%
consumo["provincia"]
# Out:
# 0        xxx
# 1        xxx
# 2        xxx
# 3        xxx
# 4        xxx
#        ...
# 246      xxx
# 247      xxx
# 248    Álava
# 249      xxx
# 250      xxx
# Name: provincia, Length: 251, dtype: object

# %%
consumo.loc[consumo["Codigo municipio"] > 45000, "provincia"] = "Bizkaia"
consumo.loc[(consumo["Codigo municipio"] < 45000) & (consumo["Codigo municipio"] > 15000) , "provincia"] = "Gipuzkoa"

# %%
print(consumo['provincia'].to_list())
# Out:
# ['Bizkaia', 'Gipuzkoa', 'Bizkaia', 'Gipuzkoa', 'Gipuzkoa', 'Gipuzkoa', 'Bizkaia', 'Gipuzkoa', 'Gipuzkoa', 'Álava', 'Gipuzkoa', 'Bizkaia', 'Gipuzkoa', 'Gipuzkoa', 'Gipuzkoa', 'Bizkaia', 'Bizkaia', 'Álava', 'Gipuzkoa', 'Gipuzkoa', 'Gipuzkoa', 'Bizkaia', 'Gipuzkoa', 'Álava', 'Bizkaia', 'Bizkaia', 'Gipuzkoa', 'Álava', 'Álava', 'Bizkaia', 'Gipuzkoa', 'Bizkaia', 'Álava', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Álava', 'Álava', 'Gipuzkoa', 'Gipuzkoa', 'Gipuzkoa', 'Bizkaia', 'Bizkaia', 'Álava', 'Gipuzkoa', 'Gipuzkoa', 'Álava', 'Bizkaia', 'Gipuzkoa', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Álava', 'Bizkaia', 'Álava', 'Gipuzkoa', 'Bizkaia', 'Gipuzkoa', 'Gipuzkoa', 'Bizkaia', 'Álava', 'Gipuzkoa', 'Gipuzkoa', 'Bizkaia', 'Álava', 'Bizkaia', 'Bizkaia', 'Gipuzkoa', 'Gipuzkoa', 'Bizkaia', 'Bizkaia', 'Álava', 'Gipuzkoa', 'Bizkaia', 'Bizkaia', 'Gipuzkoa', 'Bizkaia', 'Bizkaia', 'Gipuzkoa', 'Bizkaia', 'Álava', 'Álava', 'Gipuzkoa', 'Gipuzkoa', 'Gipuzkoa', 'Bizkaia', 'Álava', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Gipuzkoa', 'Gipuzkoa', 'Álava', 'Bizkaia', 'Gipuzkoa', 'Bizkaia', 'Bizkaia', 'Gipuzkoa', 'Bizkaia', 'Bizkaia', 'Gipuzkoa', 'Gipuzkoa', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Gipuzkoa', 'Bizkaia', 'Gipuzkoa', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Álava', 'Gipuzkoa', 'Gipuzkoa', 'Gipuzkoa', 'Gipuzkoa', 'Bizkaia', 'Gipuzkoa', 'Bizkaia', 'Gipuzkoa', 'Gipuzkoa', 'Gipuzkoa', 'Álava', 'Álava', 'Bizkaia', 'Gipuzkoa', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Álava', 'Álava', 'Álava', 'Álava', 'Álava', 'Álava', 'Bizkaia', 'Álava', 'Álava', 'Bizkaia', 'Gipuzkoa', 'Gipuzkoa', 'Álava', 'Bizkaia', 'Gipuzkoa', 'Gipuzkoa', 'Gipuzkoa', 'Gipuzkoa', 'Álava', 'Gipuzkoa', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Álava', 'Bizkaia', 'Gipuzkoa', 'Gipuzkoa', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Gipuzkoa', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Álava', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Gipuzkoa', 'Gipuzkoa', 'Bizkaia', 'Bizkaia', 'Álava', 'Gipuzkoa', 'Álava', 'Gipuzkoa', 'Bizkaia', 'Gipuzkoa', 'Gipuzkoa', 'Gipuzkoa', 'Gipuzkoa', 'Gipuzkoa', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Álava', 'Gipuzkoa', 'Gipuzkoa', 'Álava', 'Bizkaia', 'Bizkaia', 'Álava', 'Álava', 'Álava', 'Álava', 'Bizkaia', 'Gipuzkoa', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Gipuzkoa', 'Bizkaia', 'Gipuzkoa', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Bizkaia', 'Álava', 'Gipuzkoa', 'Gipuzkoa', 'Gipuzkoa', 'Álava', 'Bizkaia', 'Gipuzkoa', 'Álava', 'Álava', 'Álava', 'Bizkaia', 'Gipuzkoa', 'Álava', 'Bizkaia', 'Álava', 'Bizkaia', 'Bizkaia', 'Gipuzkoa', 'Bizkaia', 'Bizkaia', 'Gipuzkoa', 'Gipuzkoa', 'Gipuzkoa', 'Bizkaia', 'Álava', 'Bizkaia', 'Gipuzkoa', 'Álava', 'Gipuzkoa', 'Gipuzkoa']

# %%
# Cantidades por cada valor
consumo['provincia'].value_counts()
# Out:
# provincia
# Bizkaia     112
# Gipuzkoa     88
# Álava        51
# Name: count, dtype: int64

# %%
consumo['provincia'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='provincia'>

# %% [markdown]
# El parámetro `kind` es el tipo de gráfico
# * ‘line’ : line plot (default)
# * ‘bar’ : vertical bar plot
# * ‘barh’ : horizontal bar plot
# * ‘hist’ : histogram
# * ‘box’ : boxplot
# * ‘kde’ : Kernel Density Estimation plot
# * ‘density’ : same as ‘kde’
# * ‘area’ : area plot
# * ‘pie’ : pie plot
# * ‘scatter’ : scatter plot (DataFrame only)
# * ‘hexbin’ : hexbin plot (DataFrame only)

# %%
# Gráfica de las cantidades por cada valor en forma de tarta
consumo['provincia'].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Cálculo de estadísticos básicos.

# %% [markdown]
# Convertimos a float (numerico) para poder trabajar con los datos

# %%
consumo.dtypes
# Out:
# Codigo municipio      int64
# Municipio            object
# 2015                 object
# 2014                float64
# 2013                float64
# 2012                float64
# 2011                float64
# 2010                float64
# 2009                float64
# 2008                float64
# 2007                float64
# 2006                float64
# 2005                float64
# 2004                float64
# 2003                float64
# 2002                float64
# provincia            object
# dtype: object

# %% [markdown]
# Para hacer el cambio de tipos de una sola vez

# %% [markdown]
# ### Media

# %% [markdown]
# Gasto medio por municipio.

# %%
consumo.loc[:,'2015':'2002']
# Out:
#          2015      2014      2013      2012      2011      2010      2009  \
# 0    19112.86  18218.65  17007.75  17492.94  19038.20  17434.98  14902.98
# 1     1775.42   1976.36   2334.03   2674.67   2093.31   2324.47   2193.65
# 2     6626.98   6766.62   6226.93   5921.76   5488.18   5228.24   4835.82
# 3    31356.73  30456.01  31958.31  31283.90  30289.75  30512.82  29608.55
# 4     6830.56   7063.86   7381.57   7450.48   7597.10   7508.26   7420.62
# ..        ...       ...       ...       ...       ...       ...       ...
# 246   2088.98   1967.21   2155.81   2258.48   1611.92   1765.80   1795.82
# 247  14627.46  13818.31  13382.69  17124.82  17584.41  18497.73  17724.03
# 248   3475.49   3452.86   3585.49   3526.35   3733.28   3897.58   3880.25
# 249   8866.33   8520.32   8485.99   8271.42   8032.16   7900.01   7374.67
# 250  50697.97  49091.91  47509.10  49579.07  53585.17  56577.73  45270.76
#
#          2008      2007      2006      2005      2004      2003      2002
# 0    19500.46  20116.32  20306.64  19993.84  20328.15  19292.68  18073.94
# 1     2301.17   2612.19   2015.60   2270.07   2186.96   2311.37   2289.61
# 2     6010.92   6246.63   5714.46   5356.14   5042.83   4462.76   4227.28
# 3    37226.58  37006.68  37842.85  36934.28  41027.15  36532.05  37132.90
# 4     9284.10  10350.79  10289.29  10580.32  10380.22   9616.06   8897.38
# ..        ...       ...       ...       ...       ...       ...       ...
# 246   1758.68   1259.54   1315.58   2668.96   4714.38   4608.56   4248.04
# 247  16189.97   5803.96   5800.26   5373.82   5185.71   5159.19   5087.84
# 248   4097.61   4205.70   4150.84   4064.04   4112.30   3967.08   3855.15
# 249   9136.98   8739.55   9655.69   9093.28   8743.57   8313.31   7804.46
# 250  45000.57  53834.12  59396.16  52384.14  54877.85  62683.29  61094.00
#
# [251 rows x 14 columns]

# %%
consumo.dtypes
# Out:
# Codigo municipio      int64
# Municipio            object
# 2015                float64
# 2014                float64
# 2013                float64
# 2012                float64
# 2011                float64
# 2010                float64
# 2009                float64
# 2008                float64
# 2007                float64
# 2006                float64
# 2005                float64
# 2004                float64
# 2003                float64
# 2002                float64
# provincia            object
# dtype: object

# %% [markdown]
# Al usar `axis = 1` se aplica la media de manera horizontal.

# %%
consumo.loc[:,'2015':'2002'].mean(axis=1)
# Out:
# 0      18630.027857
# 1       2239.920000
# 2       5582.539286
# 3      34226.325714
# 4       8617.900714
#            ...
# 246     2444.125714
# 247    11525.728571
# 248     3857.430000
# 249     8495.552857
# 250    52970.131429
# Length: 251, dtype: float64

# %% [markdown]
# Puedo guardar el dato en una columna nueva

# %%
consumo['promedio'] = consumo.loc[:,'2015':'2002'].mean(axis=1)

# %%
consumo['promedio']
# Out:
# 0      18630.027857
# 1       2239.920000
# 2       5582.539286
# 3      34226.325714
# 4       8617.900714
#            ...
# 246     2444.125714
# 247    11525.728571
# 248     3857.430000
# 249     8495.552857
# 250    52970.131429
# Name: promedio, Length: 251, dtype: float64

# %%
consumo
# Out:
#      Codigo municipio                          Municipio      2015      2014  \
# 0               48001                            Abadiño  19112.86  18218.65
# 1               20001                       Abaltzisketa   1775.42   1976.36
# 2               48002  Abanto y Ciérvana-Abanto Zierbena   6626.98   6766.62
# 3               20002                              Aduna  31356.73  30456.01
# 4               20016                                Aia   6830.56   7063.86
# ..                ...                                ...       ...       ...
# 246             48915                    Ziortza-Bolibar   2088.98   1967.21
# 247             20028                           Zizurkil  14627.46  13818.31
# 248              1063                               Zuia   3475.49   3452.86
# 249             20081                             Zumaia   8866.33   8520.32
# 250             20080                          Zumarraga  50697.97  49091.91
#
#          2013      2012      2011      2010      2009      2008      2007  \
# 0    17007.75  17492.94  19038.20  17434.98  14902.98  19500.46  20116.32
# 1     2334.03   2674.67   2093.31   2324.47   2193.65   2301.17   2612.19
# 2     6226.93   5921.76   5488.18   5228.24   4835.82   6010.92   6246.63
# 3    31958.31  31283.90  30289.75  30512.82  29608.55  37226.58  37006.68
# 4     7381.57   7450.48   7597.10   7508.26   7420.62   9284.10  10350.79
# ..        ...       ...       ...       ...       ...       ...       ...
# 246   2155.81   2258.48   1611.92   1765.80   1795.82   1758.68   1259.54
# 247  13382.69  17124.82  17584.41  18497.73  17724.03  16189.97   5803.96
# 248   3585.49   3526.35   3733.28   3897.58   3880.25   4097.61   4205.70
# 249   8485.99   8271.42   8032.16   7900.01   7374.67   9136.98   8739.55
# 250  47509.10  49579.07  53585.17  56577.73  45270.76  45000.57  53834.12
#
#          2006      2005      2004      2003      2002 provincia      promedio
# 0    20306.64  19993.84  20328.15  19292.68  18073.94   Bizkaia  18630.027857
# 1     2015.60   2270.07   2186.96   2311.37   2289.61  Gipuzkoa   2239.920000
# 2     5714.46   5356.14   5042.83   4462.76   4227.28   Bizkaia   5582.539286
# 3    37842.85  36934.28  41027.15  36532.05  37132.90  Gipuzkoa  34226.325714
# 4    10289.29  10580.32  10380.22   9616.06   8897.38  Gipuzkoa   8617.900714
# ..        ...       ...       ...       ...       ...       ...           ...
# 246   1315.58   2668.96   4714.38   4608.56   4248.04   Bizkaia   2444.125714
# 247   5800.26   5373.82   5185.71   5159.19   5087.84  Gipuzkoa  11525.728571
# 248   4150.84   4064.04   4112.30   3967.08   3855.15     Álava   3857.430000
# 249   9655.69   9093.28   8743.57   8313.31   7804.46  Gipuzkoa   8495.552857
# 250  59396.16  52384.14  54877.85  62683.29  61094.00  Gipuzkoa  52970.131429
#
# [251 rows x 18 columns]

# %% [markdown]
# Si quisieramos el consumo medio por año tendríamos que crearlo en una serie independiente ya que el numero de elementos no coincide ni con el número de filas ni el de columnas.

# %%
consumopromedio = consumo.loc[:,'2015':'2002'].mean(axis=0)

# %%
consumopromedio
# Out:
# 2015    12605.363825
# 2014    12447.753865
# 2013    12113.322869
# 2012    12586.729124
# 2011    12983.042550
# 2010    12930.964223
# 2009    11798.075219
# 2008    14604.023984
# 2007    14566.509363
# 2006    14484.171833
# 2005    13969.053108
# 2004    14170.723904
# 2003    13481.837211
# 2002    13179.421833
# dtype: float64

# %% [markdown]
# ###Suma

# %% [markdown]
# Sumatorio del gasto por municipio

# %%
sum_gasto = consumo.loc[:,'2015':'2002'].sum(axis=1)
type(sum_gasto)
# Out:
# pandas.core.series.Series

# %%
sum_gasto
# Out:
# 0      260820.39
# 1       31358.88
# 2       78155.55
# 3      479168.56
# 4      120650.61
#          ...
# 246     34217.76
# 247    161360.20
# 248     54004.02
# 249    118937.74
# 250    741581.84
# Length: 251, dtype: float64

# %% [markdown]
# Lo podemos añadir como nueva columna

# %%
consumo["Suma"] = sum_gasto

# %%
consumo["Suma"]
# Out:
# 0      260820.39
# 1       31358.88
# 2       78155.55
# 3      479168.56
# 4      120650.61
#          ...
# 246     34217.76
# 247    161360.20
# 248     54004.02
# 249    118937.74
# 250    741581.84
# Name: Suma, Length: 251, dtype: float64

# %%
consumo.head()
# Out:
#    Codigo municipio                          Municipio      2015      2014  \
# 0             48001                            Abadiño  19112.86  18218.65
# 1             20001                       Abaltzisketa   1775.42   1976.36
# 2             48002  Abanto y Ciérvana-Abanto Zierbena   6626.98   6766.62
# 3             20002                              Aduna  31356.73  30456.01
# 4             20016                                Aia   6830.56   7063.86
#
#        2013      2012      2011      2010      2009      2008      2007  \
# 0  17007.75  17492.94  19038.20  17434.98  14902.98  19500.46  20116.32
# 1   2334.03   2674.67   2093.31   2324.47   2193.65   2301.17   2612.19
# 2   6226.93   5921.76   5488.18   5228.24   4835.82   6010.92   6246.63
# 3  31958.31  31283.90  30289.75  30512.82  29608.55  37226.58  37006.68
# 4   7381.57   7450.48   7597.10   7508.26   7420.62   9284.10  10350.79
#
#        2006      2005      2004      2003      2002 provincia      promedio  \
# 0  20306.64  19993.84  20328.15  19292.68  18073.94   Bizkaia  18630.027857
# 1   2015.60   2270.07   2186.96   2311.37   2289.61  Gipuzkoa   2239.920000
# 2   5714.46   5356.14   5042.83   4462.76   4227.28   Bizkaia   5582.539286
# 3  37842.85  36934.28  41027.15  36532.05  37132.90  Gipuzkoa  34226.325714
# 4  10289.29  10580.32  10380.22   9616.06   8897.38  Gipuzkoa   8617.900714
#
#         Suma
# 0  260820.39
# 1   31358.88
# 2   78155.55
# 3  479168.56
# 4  120650.61

# %% [markdown]
# ## Columna categórica a partir de los datos

# %% [markdown]
# Creamos una variable que nos indique si el municipio es un pueblo o una ciudad en base a un límite que establacemos (por ejemplo 50.000)

# %%
consumo['pueblociudad']='xxx'

# %%
consumo.loc[consumo["2012"] < 50000, 'pueblociudad'] = "Pueblo"
consumo.loc[consumo["2012"] >=50000, 'pueblociudad'] = "Ciudad"

# %% [markdown]
# Comprobamos la distribución de categorías en la columna creada

# %%
consumo['pueblociudad'].value_counts()
consumo['pueblociudad'].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='pueblociudad'>

# %% [markdown]
# ### Ordenaciones `sort_values()`

# %% [markdown]
# Municipios con Menor/Mayor Consumo.
#
# Orden ascendente por la variable 2015

# %%
municmenor = consumo.sort_values('2015')
municmenor.head(10)
# Out:
#      Codigo municipio     Municipio     2015     2014     2013     2012  \
# 132   62756.86   62095.40   61764.55   60213.50   55982.87   69677.76
# 179    4226.17    5402.17   14054.50    9982.39   14768.04   13249.53
# 143   77229.22   57629.47   58320.34   51315.13   63357.07   61607.52
# 14    85430.87   79463.92   78681.30   76252.74   72733.49   15153.41
# 5     95357.66  120703.86  127260.11  107453.11  136313.18  140479.44
# 187  636580.32  611536.81  559803.66  376899.12  644624.13  733540.73
#
#           2006       2005       2004       2003       2002 provincia  \
# 98    55887.65   49610.60   44619.04   41693.82   40597.67  Gipuzkoa
# 97    40321.32   38303.09   41210.90   39296.90   30651.88   Bizkaia
# 42    57339.87   57649.03   60277.70   59366.20   57474.90   Bizkaia
# 6      3120.09    3138.43    3308.67    3198.33    2953.02   Bizkaia
# 132   50480.64   57126.37   52909.33   51124.64   49757.94   Bizkaia
# 179   10707.40   11065.08    6549.77    8214.59    7088.79   Bizkaia
# 143   81602.34   61087.14   64977.34   62703.90   55790.31     Álava
# 14    20851.11   14901.42   19532.19   19646.73   18187.59  Gipuzkoa
# 5    139652.55  154155.67  159191.20  156092.21  166830.79  Gipuzkoa
# 187  723935.14  705097.82  750196.53  722920.04  668938.96  Gipuzkoa
#
#           promedio        Suma pueblociudad
# 98    49509.706429   693135.89       Ciudad
# 97    44200.075000   618801.05       Ciudad
# 42    54313.760000   760392.64       Ciudad
# 6     34114.060000   477596.84       Ciudad
# 132   58992.998571   825901.98       Ciudad
# 179   16698.337143   233776.72       Pueblo
# 143   64582.669286   904157.37       Ciudad
# 14    53831.738571   753644.34       Ciudad
# 5    130200.700714  1822809.81       Ciudad
# 187  642886.569286  9000411.97       Ciudad

# %% [markdown]
# ## Consultas.

# %% [markdown]
# Selección de las observaciones de una determinada Provincia.

# %%
datosBizkaia   = consumo[consumo['provincia']=="Bizkaia"]
datosAlava     = consumo[consumo['provincia']=="Álava"]
datosGipuzkoa  = consumo[consumo['provincia']=="Gipuzkoa"]

# %%
datosBizkaia.head()
# Out:
#     Codigo municipio                          Municipio      2015      2014  \
# 0              48001                            Abadiño  19112.86  18218.65
# 2              48002  Abanto y Ciérvana-Abanto Zierbena   6626.98   6766.62
# 6              48911                            Ajangiz  60798.19  56880.09
# 11             48912                         Alonsotegi   7325.72   7258.62
# 15             48003                  Amorebieta-Etxano  11817.98  11374.13
#
#         2013      2012      2011      2010      2009      2008      2007  \
# 0   17007.75  17492.94  19038.20  17434.98  14902.98  19500.46  20116.32
# 2    6226.93   5921.76   5488.18   5228.24   4835.82   6010.92   6246.63
# 6   57792.04  58705.44  61449.32  58778.30  49522.39  54603.87   3348.66
# 11   7465.17   6843.29   7686.73   9057.94   9871.74  11557.27  10189.12
# 15  11298.30  11564.69  11367.16  11571.38  11101.44  14162.03  14282.98
#
#         2006      2005      2004      2003      2002 provincia      promedio  \
# 0   20306.64  19993.84  20328.15  19292.68  18073.94   Bizkaia  18630.027857
# 2    5714.46   5356.14   5042.83   4462.76   4227.28   Bizkaia   5582.539286
# 6    3120.09   3138.43   3308.67   3198.33   2953.02   Bizkaia  34114.060000
# 11  10429.98  10179.93  10831.03  11215.78  10877.86   Bizkaia   9342.155714
# 15  14261.30  14104.71  13906.98  13453.65  13256.15   Bizkaia  12680.205714
#
#          Suma pueblociudad
# 0   260820.39       Pueblo
# 2    78155.55       Pueblo
# 6   477596.84       Ciudad
# 11  130790.18       Pueblo
# 15  177522.88       Pueblo

# %% [markdown]
# Consumo Máximo/Mínimo

# %%
menorconsumo = min(consumo['promedio'])
mayorconsumo = max(consumo['promedio'])

# %%
menorconsumo
# Out:
# 1830.1

# %%
mayorconsumo
# Out:
# 642886.5692857143

# %% [markdown]
# Extraemos el nombre del municipio con mayor/menor consumo

# %%
consumo['promedio'] == consumo['promedio'].min()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 246    False
# 247    False
# 248    False
# 249    False
# 250    False
# Name: promedio, Length: 251, dtype: bool

# %% [markdown]
# Este filtro nos puede servir ahora para extraer la fila buscada

# %%
consumo[consumo['promedio'] == consumo['promedio'].min()]
# Out:
#      Codigo municipio Municipio     2015     2014     2013     2012     2011  \
# 109             20907   Gaztelu  1802.34  1727.45  1916.81  2139.46  1969.76
#
#         2010     2009     2008     2007     2006    2005     2004     2003  \
# 109  1906.25  1976.43  1803.59  1934.28  1831.04  1834.5  1750.11  1769.51
#
#         2002 provincia  promedio     Suma pueblociudad
# 109  1259.87  Gipuzkoa    1830.1  25621.4       Pueblo

# %% [markdown]
# Si sólo nos interesa el nombre del municipio...

# %%
consumo['Municipio']
# Out:
# 0                                Abadiño
# 1                           Abaltzisketa
# 2      Abanto y Ciérvana-Abanto Zierbena
# 3                                  Aduna
# 4                                    Aia
#                      ...
# 246                      Ziortza-Bolibar
# 247                             Zizurkil
# 248                                 Zuia
# 249                               Zumaia
# 250                            Zumarraga
# Name: Municipio, Length: 251, dtype: object

# %%
munimenorconsumo = consumo["Municipio"][consumo['promedio'] == menorconsumo]
# O bien:
munimenorconsumo = consumo['Municipio'][consumo['promedio'] == consumo['promedio'].min()]
munimenorconsumo
# Out:
# 109    Gaztelu
# Name: Municipio, dtype: object

# %%
munimayorconsumo = consumo[consumo['promedio'] == mayorconsumo]['Municipio']
# O bien:
munimayorconsumo = consumo['Municipio'][consumo['promedio'] == consumo['promedio'].max()]
munimayorconsumo
# Out:
# 187    Olaberria
# Name: Municipio, dtype: object

# %% [markdown]
# Ambos filtrados nos han devuelto un objeto de pandas. Con su fila y su columna. Si sólo quiero el valor de la celda (un string) tengo que acceder con `values`.

# %%
munimayorconsumo.values[0]
# Out:
# 'Olaberria'

# %%
munimenorconsumo.values[0]
# Out:
# 'Gaztelu'

# %% [markdown]
# De la misma manera extraemos el nombre de la provincia en la que se encuentra el municipio con mayor/menor consumo

# %%
consumo['provincia']
# Out:
# 0       Bizkaia
# 1      Gipuzkoa
# 2       Bizkaia
# 3      Gipuzkoa
# 4      Gipuzkoa
#          ...
# 246     Bizkaia
# 247    Gipuzkoa
# 248       Álava
# 249    Gipuzkoa
# 250    Gipuzkoa
# Name: provincia, Length: 251, dtype: object

# %%
provmenorconsumo = consumo['provincia'][consumo['promedio'] == menorconsumo]
provmayorconsumo = consumo['provincia'][consumo['promedio'] == mayorconsumo]

# %%
provmenorconsumo
# Out:
# 109    Gipuzkoa
# Name: provincia, dtype: object

# %%
provmayorconsumo
# Out:
# 187    Gipuzkoa
# Name: provincia, dtype: object

# %% [markdown]
# ### Consultas con agregaciones

# %% [markdown]
# Hacer agrupaciones me permite hacer un resumen estadístico de los datos cuando tengo alguna columna categórica.

# %% [markdown]
# El resumen resultante tendrá tantas filas como categorías tenga la variable elegida para agrupar.

# %% [markdown]
# Pero, ¿Qué hace con el resto de columnas? Si tiene que agrupar los valores de esa columna le tengo que decir qué cálculo realizar con los múltiples valores a agrupar. Un cálculo de "agregación".
#
# Pongamos que le digo que agrupe los datos sumándolos.

# %%
agrupacion = consumo.groupby(['provincia']).agg("sum")
agrupacion.head()
# Out:
#            Codigo municipio  \
# provincia
# Bizkaia             5394373
# Gipuzkoa            1769649
# Álava                 54420
#
#                                                    Municipio        2015  \
# provincia
# Bizkaia    AbadiñoAbanto y Ciérvana-Abanto ZierbenaAjangi...  1078305.11
# Gipuzkoa   AbaltzisketaAdunaAiaAizarnazabalAlbizturAlegia...  1565879.96
# Álava      Alegría-DulantziAmurrioAramaioArmiñónArraia-Ma...   519761.25
#
#                  2014        2013        2012        2011        2010  \
# provincia
# Bizkaia    1030513.26   970252.41  1001914.86  1066756.39  1093051.76
# Gipuzkoa   1575313.20  1564899.99  1624252.62  1656195.25  1631074.34
# Álava       518559.76   505291.64   533101.53   535792.04   521545.92
#
#                  2009        2008        2007        2006        2005  \
# provincia
# Bizkaia    1036529.52  1201830.96  1138995.16  1104694.48  1078753.14
# Gipuzkoa   1423914.17  1855829.10  1908314.55  1902322.10  1849477.40
# Álava       500873.19   607949.96   608884.14   628510.55   578001.79
#
#                  2004        2003        2002      promedio         Suma  \
# provincia
# Bizkaia    1070563.16  1002252.04   970365.34  1.060341e+06  14844777.59
# Gipuzkoa   1906365.89  1826226.24  1798592.16  1.720618e+06  24088656.97
# Álava       579922.65   555462.86   539077.38  5.523382e+05   7732734.66
#
#                                                 pueblociudad
# provincia
# Bizkaia    PuebloPuebloCiudadPuebloPuebloPuebloPuebloPueb...
# Gipuzkoa   PuebloPuebloPuebloCiudadPuebloPuebloPuebloPueb...
# Álava      PuebloPuebloPuebloPuebloPuebloPuebloPuebloPueb...

# %% [markdown]
# Las columnas "Municipio" y "pueblociudad" son de texto, así que al sumar los strings los ha concatenado.
#
# Al menos, esto lo puede hacer, ya que si le hubiera pedido que agregara con la media habría sido imposible.

# %% [markdown]
# Voy a eliminar las columnas de texto y a calcular el consumo medio por provincia

# %%
consumo_num = consumo.drop(["Municipio", "pueblociudad"], axis = 1)

# %%
agrupacion = consumo_num.groupby(['provincia']).agg("mean")

# %%
agrupacion
# Out:
#            Codigo municipio          2015          2014          2013  \
# provincia
# Bizkaia        48164.044643   9627.724196   9201.011250   8662.967946
# Gipuzkoa       20109.647727  17794.090455  17901.286364  17782.954432
# Álava           1067.058824  10191.397059  10167.838431   9907.679216
#
#                    2012          2011          2010          2009  \
# provincia
# Bizkaia     8945.668393   9524.610625   9759.390714   9254.727857
# Gipuzkoa   18457.416136  18820.400568  18534.935682  16180.842841
# Álava      10452.971176  10505.726275  10226.390588   9821.042941
#
#                    2008          2007          2006          2005  \
# provincia
# Bizkaia    10730.633571  10169.599643   9863.343571   9631.724464
# Gipuzkoa   21088.967045  21685.392614  21617.296591  21016.788636
# Álava      11920.587451  11938.904706  12323.736275  11333.368431
#
#                    2004          2003          2002      promedio  \
# provincia
# Bizkaia     9558.599643   8948.678929   8663.976250   9467.332647
# Gipuzkoa   21663.248750  20752.570909  20438.547273  19552.481307
# Álava      11371.032353  10891.428627  10570.144706  10830.160588
#
#                     Suma
# provincia
# Bizkaia    132542.657054
# Gipuzkoa   273734.738295
# Álava      151622.248235

# %%
agrupacion.loc[["Bizkaia","Álava"], "2015"]
# Out:
# provincia
# Bizkaia     9627.724196
# Álava      10191.397059
# Name: 2015, dtype: float64

# %%
consmedioprov = consumo_num.groupby(['provincia']).agg("mean").reset_index()
consmedioprov
# Out:
#   provincia  Codigo municipio          2015          2014          2013  \
# 0   Bizkaia      48164.044643   9627.724196   9201.011250   8662.967946
# 1  Gipuzkoa      20109.647727  17794.090455  17901.286364  17782.954432
# 2     Álava       1067.058824  10191.397059  10167.838431   9907.679216
#
#            2012          2011          2010          2009          2008  \
# 0   8945.668393   9524.610625   9759.390714   9254.727857  10730.633571
# 1  18457.416136  18820.400568  18534.935682  16180.842841  21088.967045
# 2  10452.971176  10505.726275  10226.390588   9821.042941  11920.587451
#
#            2007          2006          2005          2004          2003  \
# 0  10169.599643   9863.343571   9631.724464   9558.599643   8948.678929
# 1  21685.392614  21617.296591  21016.788636  21663.248750  20752.570909
# 2  11938.904706  12323.736275  11333.368431  11371.032353  10891.428627
#
#            2002      promedio           Suma
# 0   8663.976250   9467.332647  132542.657054
# 1  20438.547273  19552.481307  273734.738295
# 2  10570.144706  10830.160588  151622.248235

# %%
consmedioprov = consmedioprov.loc[:,('provincia','promedio')]

# %%
consmedioprov
# Out:
#   provincia      promedio
# 0   Bizkaia   9467.332647
# 1  Gipuzkoa  19552.481307
# 2     Álava  10830.160588

# %% [markdown]
# Todo en un único paso

# %%
consmedioprov2 = (consumo_num.loc[:,('provincia','promedio')]).groupby(['provincia',]).agg("mean").reset_index()

# %%
consmedioprov2
# Out:
#   provincia      promedio
# 0   Bizkaia   9467.332647
# 1  Gipuzkoa  19552.481307
# 2     Álava  10830.160588

# %% [markdown]
# Consumo  total por provincia

# %%
constotprov = consumo_num.groupby(['provincia']).agg("sum").reset_index()
constotprov = constotprov.loc[:,('provincia','Suma')]

# %%
constotprov
# Out:
#   provincia         Suma
# 0   Bizkaia  14844777.59
# 1  Gipuzkoa  24088656.97
# 2     Álava   7732734.66

# %% [markdown]
# Todo en un único paso

# %%
constotprov2 = (consumo.loc[:,('provincia','Suma')]).groupby(['provincia',]).agg("sum").reset_index()

# %%
constotprov2
# Out:
#   provincia         Suma
# 0   Bizkaia  14844777.59
# 1  Gipuzkoa  24088656.97
# 2     Álava   7732734.66

# %% [markdown]
# ## Operaciones con variables.

# %% [markdown]
# Consumo por categorías Alto/Medio/Bajo.
#
# Podemos clasificar los municipios en consumo alto/medio/bajo según sus percentiles

# %%
consumo_p33_prov = consumo_num["promedio"].groupby(consumo['provincia']).quantile(q=0.33).reset_index()

# %%
consumo_p33_prov
# Out:
#   provincia     promedio
# 0   Bizkaia  3108.363543
# 1  Gipuzkoa  4173.691993
# 2     Álava  4090.734286

# %%
consumo_p66_prov = consumo["promedio"].groupby(consumo['provincia']).quantile(q=0.67).reset_index()

# %%
consumo_p66_prov
# Out:
#   provincia      promedio
# 0   Bizkaia   6738.368436
# 1  Gipuzkoa   9100.159107
# 2     Álava  10106.950000

# %% [markdown]
# ## Unión de varias tablas.

# %% [markdown]
# Unimos los resultados obtenidos en una única tabla
#
# Los unimos utilizando la columna común 'provincia' como clave para indicar las filas que se corresponden.

# %%
consum_33_66 = pd.merge(consumo_p33_prov, consumo_p66_prov, on='provincia')

# %%
consum_33_66
# Out:
#   provincia   promedio_x    promedio_y
# 0   Bizkaia  3108.363543   6738.368436
# 1  Gipuzkoa  4173.691993   9100.159107
# 2     Álava  4090.734286  10106.950000

# %% [markdown]
# Hay que cambiar el nombre a las variables/columnas (axis=1)

# %%
consum_33_66 = consum_33_66.rename({'promedio_x':'p33','promedio_y':'p66'},axis=1)
consum_33_66
# Out:
#   provincia          p33           p66
# 0   Bizkaia  3108.363543   6738.368436
# 1  Gipuzkoa  4173.691993   9100.159107
# 2     Álava  4090.734286  10106.950000

# %% [markdown]
# Ahora lo unimos con el dataset

# %%
consumo = pd.merge(consumo, consum_33_66, on = 'provincia')

# %%
consumo
# Out:
#      Codigo municipio                          Municipio      2015      2014  \
# 0               48001                            Abadiño  19112.86  18218.65
# 1               20001                       Abaltzisketa   1775.42   1976.36
# 2               48002  Abanto y Ciérvana-Abanto Zierbena   6626.98   6766.62
# 3               20002                              Aduna  31356.73  30456.01
# 4               20016                                Aia   6830.56   7063.86
# ..                ...                                ...       ...       ...
# 246             48915                    Ziortza-Bolibar   2088.98   1967.21
# 247             20028                           Zizurkil  14627.46  13818.31
# 248              1063                               Zuia   3475.49   3452.86
# 249             20081                             Zumaia   8866.33   8520.32
# 250             20080                          Zumarraga  50697.97  49091.91
#
#          2013      2012      2011      2010      2009      2008  ...  \
# 0    17007.75  17492.94  19038.20  17434.98  14902.98  19500.46  ...
# 1     2334.03   2674.67   2093.31   2324.47   2193.65   2301.17  ...
# 2     6226.93   5921.76   5488.18   5228.24   4835.82   6010.92  ...
# 3    31958.31  31283.90  30289.75  30512.82  29608.55  37226.58  ...
# 4     7381.57   7450.48   7597.10   7508.26   7420.62   9284.10  ...
# ..        ...       ...       ...       ...       ...       ...  ...
# 246   2155.81   2258.48   1611.92   1765.80   1795.82   1758.68  ...
# 247  13382.69  17124.82  17584.41  18497.73  17724.03  16189.97  ...
# 248   3585.49   3526.35   3733.28   3897.58   3880.25   4097.61  ...
# 249   8485.99   8271.42   8032.16   7900.01   7374.67   9136.98  ...
# 250  47509.10  49579.07  53585.17  56577.73  45270.76  45000.57  ...
#
#          2005      2004      2003      2002  provincia      promedio  \
# 0    19993.84  20328.15  19292.68  18073.94    Bizkaia  18630.027857
# 1     2270.07   2186.96   2311.37   2289.61   Gipuzkoa   2239.920000
# 2     5356.14   5042.83   4462.76   4227.28    Bizkaia   5582.539286
# 3    36934.28  41027.15  36532.05  37132.90   Gipuzkoa  34226.325714
# 4    10580.32  10380.22   9616.06   8897.38   Gipuzkoa   8617.900714
# ..        ...       ...       ...       ...        ...           ...
# 246   2668.96   4714.38   4608.56   4248.04    Bizkaia   2444.125714
# 247   5373.82   5185.71   5159.19   5087.84   Gipuzkoa  11525.728571
# 248   4064.04   4112.30   3967.08   3855.15      Álava   3857.430000
# 249   9093.28   8743.57   8313.31   7804.46   Gipuzkoa   8495.552857
# 250  52384.14  54877.85  62683.29  61094.00   Gipuzkoa  52970.131429
#
#           Suma  pueblociudad          p33           p66
# 0    260820.39        Pueblo  3108.363543   6738.368436
# 1     31358.88        Pueblo  4173.691993   9100.159107
# 2     78155.55        Pueblo  3108.363543   6738.368436
# 3    479168.56        Pueblo  4173.691993   9100.159107
# 4    120650.61        Pueblo  4173.691993   9100.159107
# ..         ...           ...          ...           ...
# 246   34217.76        Pueblo  3108.363543   6738.368436
# 247  161360.20        Pueblo  4173.691993   9100.159107
# 248   54004.02        Pueblo  4090.734286  10106.950000
# 249  118937.74        Pueblo  4173.691993   9100.159107
# 250  741581.84        Pueblo  4173.691993   9100.159107
#
# [251 rows x 22 columns]

# %% [markdown]
# Una vez que tenemos los valores, podemos realizar la clasificación. Muy similar a cuando creamos la columna "provincia" pero ahora la comparación no se hace con un número fijo sino con el valor de otra columna.

# %%
consumo['consumoProvincia']='xxx'

consumo.loc[consumo["promedio"] < consumo['p33'], 'consumoProvincia'] = "Bajo"

consumo.loc[(consumo["promedio"] > consumo['p33']) &
            (consumo["promedio"] < consumo['p66']), 'consumoProvincia'] = "Medio"

consumo.loc[consumo["promedio"] > consumo['p66'], 'consumoProvincia'] = "Alto"

# %%
consumo["consumoProvincia"].value_counts()
# Out:
# consumoProvincia
# Medio    85
# Alto     83
# Bajo     83
# Name: count, dtype: int64

# %%
consumo
# Out:
#      Codigo municipio                          Municipio      2015      2014  \
# 0               48001                            Abadiño  19112.86  18218.65
# 1               20001                       Abaltzisketa   1775.42   1976.36
# 2               48002  Abanto y Ciérvana-Abanto Zierbena   6626.98   6766.62
# 3               20002                              Aduna  31356.73  30456.01
# 4               20016                                Aia   6830.56   7063.86
# ..                ...                                ...       ...       ...
# 246             48915                    Ziortza-Bolibar   2088.98   1967.21
# 247             20028                           Zizurkil  14627.46  13818.31
# 248              1063                               Zuia   3475.49   3452.86
# 249             20081                             Zumaia   8866.33   8520.32
# 250             20080                          Zumarraga  50697.97  49091.91
#
#          2013      2012      2011      2010      2009      2008  ...  \
# 0    17007.75  17492.94  19038.20  17434.98  14902.98  19500.46  ...
# 1     2334.03   2674.67   2093.31   2324.47   2193.65   2301.17  ...
# 2     6226.93   5921.76   5488.18   5228.24   4835.82   6010.92  ...
# 3    31958.31  31283.90  30289.75  30512.82  29608.55  37226.58  ...
# 4     7381.57   7450.48   7597.10   7508.26   7420.62   9284.10  ...
# ..        ...       ...       ...       ...       ...       ...  ...
# 246   2155.81   2258.48   1611.92   1765.80   1795.82   1758.68  ...
# 247  13382.69  17124.82  17584.41  18497.73  17724.03  16189.97  ...
# 248   3585.49   3526.35   3733.28   3897.58   3880.25   4097.61  ...
# 249   8485.99   8271.42   8032.16   7900.01   7374.67   9136.98  ...
# 250  47509.10  49579.07  53585.17  56577.73  45270.76  45000.57  ...
#
#          2004      2003      2002  provincia      promedio       Suma  \
# 0    20328.15  19292.68  18073.94    Bizkaia  18630.027857  260820.39
# 1     2186.96   2311.37   2289.61   Gipuzkoa   2239.920000   31358.88
# 2     5042.83   4462.76   4227.28    Bizkaia   5582.539286   78155.55
# 3    41027.15  36532.05  37132.90   Gipuzkoa  34226.325714  479168.56
# 4    10380.22   9616.06   8897.38   Gipuzkoa   8617.900714  120650.61
# ..        ...       ...       ...        ...           ...        ...
# 246   4714.38   4608.56   4248.04    Bizkaia   2444.125714   34217.76
# 247   5185.71   5159.19   5087.84   Gipuzkoa  11525.728571  161360.20
# 248   4112.30   3967.08   3855.15      Álava   3857.430000   54004.02
# 249   8743.57   8313.31   7804.46   Gipuzkoa   8495.552857  118937.74
# 250  54877.85  62683.29  61094.00   Gipuzkoa  52970.131429  741581.84
#
#     pueblociudad          p33           p66 consumoProvincia
# 0         Pueblo  3108.363543   6738.368436             Alto
# 1         Pueblo  4173.691993   9100.159107             Bajo
# 2         Pueblo  3108.363543   6738.368436            Medio
# 3         Pueblo  4173.691993   9100.159107             Alto
# 4         Pueblo  4173.691993   9100.159107            Medio
# ..           ...          ...           ...              ...
# 246       Pueblo  3108.363543   6738.368436             Bajo
# 247       Pueblo  4173.691993   9100.159107             Alto
# 248       Pueblo  4090.734286  10106.950000             Bajo
# 249       Pueblo  4173.691993   9100.159107            Medio
# 250       Pueblo  4173.691993   9100.159107             Alto
#
# [251 rows x 23 columns]

# %% [markdown]
# ## Cálculos numéricos con columnas

# %% [markdown]
# Diferencias a lo largo del periodo. Sólo tenemos en cuenta el primer y último año

# %%
consumo['dif1502'] = consumo['2015'] - consumo['2002']

# %%
consumo['dif1502']
# Out:
# 0       1038.92
# 1       -514.19
# 2       2399.70
# 3      -5776.17
# 4      -2066.82
#          ...
# 246    -2159.06
# 247     9539.62
# 248     -379.66
# 249     1061.87
# 250   -10396.03
# Name: dif1502, Length: 251, dtype: float64

# %% [markdown]
# Y ordenarlos segun esas diferencias

# %%
consumo2 = consumo.sort_values('dif1502')

# %%
consumo2
# Out:
#      Codigo municipio       Municipio       2015       2014       2013  \
# 68              20023         Berrobi    2411.14    8374.65   36029.70
# 5               20003    Aizarnazabal  101231.41  106143.00  111945.62
# 46              20018        Azpeitia    5297.03    5056.98    8354.20
# 187             20058       Olaberria  641676.36  640347.72  584314.63
# 69              20024  Bidania-Goiatz   11541.67   11310.44   10663.47
# ..                ...             ...        ...        ...        ...
# 97              48030      Etxebarria   55531.54   52542.84   50444.61
# 244             48913        Zierbena   45732.44   34891.95   30812.56
# 6               48911         Ajangiz   60798.19   56880.09   57792.04
# 179             48071          Muskiz   68820.68   55164.21    4483.40
# 14              20008        Amezketa   81716.04   86473.23   84620.30
#
#           2012       2011       2010       2009       2008  ...       2003  \
# 68    37091.56   35876.25   37624.60   47023.18   58957.86  ...   59297.30
# 5     95357.66  120703.86  127260.11  107453.11  136313.18  ...  156092.21
# 46    12603.00   26063.97   49041.69   60215.32   57895.92  ...   46566.32
# 187  636580.32  611536.81  559803.66  376899.12  644624.13  ...  722920.04
# 69    10841.22   11725.58   13278.90   14466.64   22180.60  ...   30752.24
# ..         ...        ...        ...        ...        ...  ...        ...
# 97    50851.25   49067.37   45882.35   37776.68   44308.51  ...   39296.90
# 244   36686.19   39654.72   47372.97   49162.84   55604.65  ...   20059.96
# 6     58705.44   61449.32   58778.30   49522.39   54603.87  ...    3198.33
# 179    4226.17    5402.17   14054.50    9982.39   14768.04  ...    8214.59
# 14    85430.87   79463.92   78681.30   76252.74   72733.49  ...   19646.73
#
#           2002  provincia       promedio        Suma  pueblociudad  \
# 68    68970.45   Gipuzkoa   46545.312857   651634.38        Pueblo
# 5    166830.79   Gipuzkoa  130200.700714  1822809.81        Ciudad
# 46    45918.27   Gipuzkoa   38189.010714   534646.15        Pueblo
# 187  668938.96   Gipuzkoa  642886.569286  9000411.97        Ciudad
# 69    34126.41   Gipuzkoa   21069.189286   294968.65        Pueblo
# ..         ...        ...            ...         ...           ...
# 97    30651.88    Bizkaia   44200.075000   618801.05        Ciudad
# 244   16554.04    Bizkaia   39794.665714   557125.32        Pueblo
# 6      2953.02    Bizkaia   34114.060000   477596.84        Ciudad
# 179    7088.79    Bizkaia   16698.337143   233776.72        Pueblo
# 14    18187.59   Gipuzkoa   53831.738571   753644.34        Ciudad
#
#              p33          p66  consumoProvincia   dif1502
# 68   4173.691993  9100.159107              Alto -66559.31
# 5    4173.691993  9100.159107              Alto -65599.38
# 46   4173.691993  9100.159107              Alto -40621.24
# 187  4173.691993  9100.159107              Alto -27262.60
# 69   4173.691993  9100.159107              Alto -22584.74
# ..           ...          ...               ...       ...
# 97   3108.363543  6738.368436              Alto  24879.66
# 244  3108.363543  6738.368436              Alto  29178.40
# 6    3108.363543  6738.368436              Alto  57845.17
# 179  3108.363543  6738.368436              Alto  61731.89
# 14   4173.691993  9100.159107              Alto  63528.45
#
# [251 rows x 24 columns]

# %% [markdown]
# ## Muestra de datos.

# %% [markdown]
# Y mostrar los 10 en los que más se ha incrementado o disminuido el consumo

# %%
consumo2.head(n=10)
# Out:
#      Codigo municipio       Municipio       2015       2014       2013  \
# 68              20023         Berrobi    2411.14    8374.65   36029.70
# 5               20003    Aizarnazabal  101231.41  106143.00  111945.62
# 46              20018        Azpeitia    5297.03    5056.98    8354.20
# 187             20058       Olaberria  641676.36  640347.72  584314.63
# 69              20024  Bidania-Goiatz   11541.67   11310.44   10663.47
# 63              20074         Bergara    7759.32    7709.92    6994.57
# 237             48097        Zaratamo    8136.56    7874.74    8535.16
# 96              48029       Etxebarri   10735.80    9408.95   10463.81
# 98   49692.21  43497.81  41149.54  54728.11  ...  41693.82  40597.67
# 132  62095.40  61764.55  60213.50  55982.87  ...  51124.64  49757.94
# 61   41685.48  35289.13  35287.67  42572.91  ...  26317.28  21787.39
# 143  57629.47  58320.34  51315.13  63357.07  ...  62703.90  55790.31
# 97   49067.37  45882.35  37776.68  44308.51  ...  39296.90  30651.88
# 244  39654.72  47372.97  49162.84  55604.65  ...  20059.96  16554.04
# 6    61449.32  58778.30  49522.39  54603.87  ...   3198.33   2953.02
# 179   5402.17  14054.50   9982.39  14768.04  ...   8214.59   7088.79
# 14   79463.92  78681.30  76252.74  72733.49  ...  19646.73  18187.59
#
#      provincia      promedio       Suma  pueblociudad          p33  \
# 247   Gipuzkoa  11525.728571  161360.20        Pueblo  4173.691993
# 98    Gipuzkoa  49509.706429  693135.89        Ciudad  4173.691993
# 132    Bizkaia  58992.998571  825901.98        Ciudad  3108.363543
# 61       Álava  36600.832857  512411.66        Pueblo  4090.734286
# 143      Álava  64582.669286  904157.37        Ciudad  4090.734286
# 97     Bizkaia  44200.075000  618801.05        Ciudad  3108.363543
# 244    Bizkaia  39794.665714  557125.32        Pueblo  3108.363543
# 6      Bizkaia  34114.060000  477596.84        Ciudad  3108.363543
# 179    Bizkaia  16698.337143  233776.72        Pueblo  3108.363543
# 14    Gipuzkoa  53831.738571  753644.34        Ciudad  4173.691993
#
#               p66  consumoProvincia   dif1502
# 247   9100.159107              Alto   9539.62
# 98    9100.159107              Alto  12284.55
# 132   6738.368436              Alto  14712.37
# 61   10106.950000              Alto  16755.14
# 143  10106.950000              Alto  17966.29
# 97    6738.368436              Alto  24879.66
# 244   6738.368436              Alto  29178.40
# 6     6738.368436              Alto  57845.17
# 179   6738.368436              Alto  61731.89
# 14    9100.159107              Alto  63528.45
#
# [10 rows x 24 columns]

# %% [markdown]
# Podemos mostrar las columnas que nos interese

# %%
consumo2.iloc[:,[0,1,-2,-1]].head(n=10)
# Out:
#      Codigo municipio       Municipio consumoProvincia   dif1502
# 68              20023         Berrobi             Alto -66559.31
# 5               20003    Aizarnazabal             Alto -65599.38
# 46              20018        Azpeitia             Alto -40621.24
# 187             20058       Olaberria             Alto -27262.60
# 69              20024  Bidania-Goiatz             Alto -22584.74
# 63              20074         Bergara             Alto -21549.28
# 237             48097        Zaratamo             Alto -17681.05
# 96              48029       Etxebarri             Alto -13964.40
# 125             20044     Ikaztegieta            Medio -13447.55
# 154              1058         Legutio             Alto -13168.94

# %%
consumo2.iloc[:,[0,1,-2,-1]].tail(n=10)
# Out:
#      Codigo municipio     Municipio consumoProvincia   dif1502
# 247             20028      Zizurkil             Alto   9539.62
# 98              20035  Ezkio-Itsaso             Alto  12284.55
# 132             48910       Iurreta             Alto  14712.37
# 61               1014  Berantevilla             Alto  16755.14
# 143              1902      Lantarón             Alto  17966.29
# 97              48030    Etxebarria             Alto  24879.66
# 244             48913      Zierbena             Alto  29178.40
# 6               48911       Ajangiz             Alto  57845.17
# 179             48071        Muskiz             Alto  61731.89
# 14              20008      Amezketa             Alto  63528.45

# %% [markdown]
# ## Guardar los datos modificados en un CSV

# %%
consumo2.to_csv('prueba.csv', encoding = "utf-8", sep = ",", index = False)

consumo_recargado=pd.read_csv("prueba.csv",sep=",",encoding='utf-8')

# %%
consumo_recargado
# Out:
#      Codigo municipio       Municipio       2015       2014       2013  \
# 0               20023         Berrobi    2411.14    8374.65   36029.70
# 1               20003    Aizarnazabal  101231.41  106143.00  111945.62
# 2               20018        Azpeitia    5297.03    5056.98    8354.20
# 3               20058       Olaberria  641676.36  640347.72  584314.63
# 4               20024  Bidania-Goiatz   11541.67   11310.44   10663.47
# ..                ...             ...        ...        ...        ...
# 246             48030      Etxebarria   55531.54   52542.84   50444.61
# 247             48913        Zierbena   45732.44   34891.95   30812.56
# 248             48911         Ajangiz   60798.19   56880.09   57792.04
# 249             48071          Muskiz   68820.68   55164.21    4483.40
# 250             20008        Amezketa   81716.04   86473.23   84620.30
#
#           2012       2011       2010       2009       2008  ...       2003  \
# 0     37091.56   35876.25   37624.60   47023.18   58957.86  ...   59297.30
# 1     95357.66  120703.86  127260.11  107453.11  136313.18  ...  156092.21
# 2     12603.00   26063.97   49041.69   60215.32   57895.92  ...   46566.32
# 3    636580.32  611536.81  559803.66  376899.12  644624.13  ...  722920.04
# 4     10841.22   11725.58   13278.90   14466.64   22180.60  ...   30752.24
# ..         ...        ...        ...        ...        ...  ...        ...
# 246   50851.25   49067.37   45882.35   37776.68   44308.51  ...   39296.90
# 247   36686.19   39654.72   47372.97   49162.84   55604.65  ...   20059.96
# 248   58705.44   61449.32   58778.30   49522.39   54603.87  ...    3198.33
# 249    4226.17    5402.17   14054.50    9982.39   14768.04  ...    8214.59
# 250   85430.87   79463.92   78681.30   76252.74   72733.49  ...   19646.73
#
#           2002  provincia       promedio        Suma  pueblociudad  \
# 0     68970.45   Gipuzkoa   46545.312857   651634.38        Pueblo
# 1    166830.79   Gipuzkoa  130200.700714  1822809.81        Ciudad
# 2     45918.27   Gipuzkoa   38189.010714   534646.15        Pueblo
# 3    668938.96   Gipuzkoa  642886.569286  9000411.97        Ciudad
# 4     34126.41   Gipuzkoa   21069.189286   294968.65        Pueblo
# ..         ...        ...            ...         ...           ...
# 246   30651.88    Bizkaia   44200.075000   618801.05        Ciudad
# 247   16554.04    Bizkaia   39794.665714   557125.32        Pueblo
# 248    2953.02    Bizkaia   34114.060000   477596.84        Ciudad
# 249    7088.79    Bizkaia   16698.337143   233776.72        Pueblo
# 250   18187.59   Gipuzkoa   53831.738571   753644.34        Ciudad
#
#              p33          p66  consumoProvincia   dif1502
# 0    4173.691993  9100.159107              Alto -66559.31
# 1    4173.691993  9100.159107              Alto -65599.38
# 2    4173.691993  9100.159107              Alto -40621.24
# 3    4173.691993  9100.159107              Alto -27262.60
# 4    4173.691993  9100.159107              Alto -22584.74
# ..           ...          ...               ...       ...
# 246  3108.363543  6738.368436              Alto  24879.66
# 247  3108.363543  6738.368436              Alto  29178.40
# 248  3108.363543  6738.368436              Alto  57845.17
# 249  3108.363543  6738.368436              Alto  61731.89
# 250  4173.691993  9100.159107              Alto  63528.45
#
# [251 rows x 24 columns]

# %% [markdown]
# Observamos que al recargar el índice se ha perdido

# %%
consumo2
# Out:
#      Codigo municipio       Municipio       2015       2014       2013  \
# 68              20023         Berrobi    2411.14    8374.65   36029.70
# 5               20003    Aizarnazabal  101231.41  106143.00  111945.62
# 46              20018        Azpeitia    5297.03    5056.98    8354.20
# 187             20058       Olaberria  641676.36  640347.72  584314.63
# 69              20024  Bidania-Goiatz   11541.67   11310.44   10663.47
# ..                ...             ...        ...        ...        ...
# 97              48030      Etxebarria   55531.54   52542.84   50444.61
# 244             48913        Zierbena   45732.44   34891.95   30812.56
# 6               48911         Ajangiz   60798.19   56880.09   57792.04
# 179             48071          Muskiz   68820.68   55164.21    4483.40
# 14              20008        Amezketa   81716.04   86473.23   84620.30
#
#           2012       2011       2010       2009       2008  ...       2003  \
# 68    37091.56   35876.25   37624.60   47023.18   58957.86  ...   59297.30
# 5     95357.66  120703.86  127260.11  107453.11  136313.18  ...  156092.21
# 46    12603.00   26063.97   49041.69   60215.32   57895.92  ...   46566.32
# 187  636580.32  611536.81  559803.66  376899.12  644624.13  ...  722920.04
# 69    10841.22   11725.58   13278.90   14466.64   22180.60  ...   30752.24
# ..         ...        ...        ...        ...        ...  ...        ...
# 97    50851.25   49067.37   45882.35   37776.68   44308.51  ...   39296.90
# 244   36686.19   39654.72   47372.97   49162.84   55604.65  ...   20059.96
# 6     58705.44   61449.32   58778.30   49522.39   54603.87  ...    3198.33
# 179    4226.17    5402.17   14054.50    9982.39   14768.04  ...    8214.59
# 14    85430.87   79463.92   78681.30   76252.74   72733.49  ...   19646.73
#
#           2002  provincia       promedio        Suma  pueblociudad  \
# 68    68970.45   Gipuzkoa   46545.312857   651634.38        Pueblo
# 5    166830.79   Gipuzkoa  130200.700714  1822809.81        Ciudad
# 46    45918.27   Gipuzkoa   38189.010714   534646.15        Pueblo
# 187  668938.96   Gipuzkoa  642886.569286  9000411.97        Ciudad
# 69    34126.41   Gipuzkoa   21069.189286   294968.65        Pueblo
# ..         ...        ...            ...         ...           ...
# 97    30651.88    Bizkaia   44200.075000   618801.05        Ciudad
# 244   16554.04    Bizkaia   39794.665714   557125.32        Pueblo
# 6      2953.02    Bizkaia   34114.060000   477596.84        Ciudad
# 179    7088.79    Bizkaia   16698.337143   233776.72        Pueblo
# 14    18187.59   Gipuzkoa   53831.738571   753644.34        Ciudad
#
#              p33          p66  consumoProvincia   dif1502
# 68   4173.691993  9100.159107              Alto -66559.31
# 5    4173.691993  9100.159107              Alto -65599.38
# 46   4173.691993  9100.159107              Alto -40621.24
# 187  4173.691993  9100.159107              Alto -27262.60
# 69   4173.691993  9100.159107              Alto -22584.74
# ..           ...          ...               ...       ...
# 97   3108.363543  6738.368436              Alto  24879.66
# 244  3108.363543  6738.368436              Alto  29178.40
# 6    3108.363543  6738.368436              Alto  57845.17
# 179  3108.363543  6738.368436              Alto  61731.89
# 14   4173.691993  9100.159107              Alto  63528.45
#
# [251 rows x 24 columns]
