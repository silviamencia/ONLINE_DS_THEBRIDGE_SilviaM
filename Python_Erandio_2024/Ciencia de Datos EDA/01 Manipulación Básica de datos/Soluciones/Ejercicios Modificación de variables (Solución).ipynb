# %% [markdown]
# # Establecemos el directorio de trabajo

# %%
import os
os.chdir(r"/content/sample_data/")

import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Cargar los datos de Train.

# %%
datos = pd.read_csv("/content/sample_data/train.csv")

# %%
datos.tail(20)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1440  1441          70       RL         79.0    11526   Pave   NaN      IR1
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1442  1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1443  1444          30       RL          NaN     8854   Pave   NaN      Reg
# 1444  1445          20       RL         63.0     8500   Pave   NaN      Reg
# 1445  1446          85       RL         70.0     8400   Pave   NaN      Reg
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1448  1449          50       RL         70.0    11767   Pave   NaN      Reg
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
datos.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# ...

# %%
datos.describe(include="all").T.head(20)
# Out:
#                count unique     top  freq          mean          std     min  \
# Id            1460.0    NaN     NaN   NaN         730.5   421.610009     1.0
# MSSubClass    1460.0    NaN     NaN   NaN      56.89726    42.300571    20.0
# MSZoning        1460      5      RL  1151           NaN          NaN     NaN
# LotFrontage   1201.0    NaN     NaN   NaN     70.049958    24.284752    21.0
# LotArea       1460.0    NaN     NaN   NaN  10516.828082  9981.264932  1300.0
# Street          1460      2    Pave  1454           NaN          NaN     NaN
# Alley             91      2    Grvl    50           NaN          NaN     NaN
# LotShape        1460      4     Reg   925           NaN          NaN     NaN
# LandContour     1460      4     Lvl  1311           NaN          NaN     NaN
# Utilities       1460      2  AllPub  1459           NaN          NaN     NaN
# LotConfig       1460      5  Inside  1052           NaN          NaN     NaN
# ...

# %% [markdown]
# # 2. Para la variable “MSZoning” eliminar de la valor “C (all)” y convertirlo en "C".

# %%
datos['MSZoning'].dtype
# Out:
# dtype('O')

# %%
datos["MSZoning"].unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
datos["MSZoning"]=datos["MSZoning"].str.replace("C (all)","C")

# %%
datos["MSZoning"].value_counts()
# Out:
# MSZoning
# RL    1151
# RM     218
# FV      65
# RH      16
# C       10
# Name: count, dtype: int64

# %% [markdown]
# # 3. Comprobar que se ha realizado correctamente el cambio.

# %%
datos["MSZoning"].unique()
# Out:
# array(['RL', 'RM', 'C', 'FV', 'RH'], dtype=object)

# %% [markdown]
# Hacer el mismo cambio, pero no como texto sino como categoría, usando los métodos de DataFrame.cat

# %%
datos["MSZoning"]=datos["MSZoning"].astype("category")
datos["MSZoning"]=datos["MSZoning"].cat.rename_categories({"C (all)": "C", "FV": "fv"})

# %%
datos["MSZoning"].unique()
# Out:
# ['RL', 'RM', 'C', 'fv', 'RH']
# Categories (5, object): ['C', 'fv', 'RH', 'RL', 'RM']

# %% [markdown]
# # 4. Crear una nueva variable que se llame Crisis.

# %%
datos['Crisis']='xxx'

# %% [markdown]
# # 5. Convertir esa columna en un valor booleano
# Transformar la variable anterior para determinar (Debe tomar los valores Sí o No), basándose en la variable “YrSold”, si la casa se vendió en el periodo sin crisis (antes de 2008) o tras el estallido de la crisis (a partir de 2008).

# %%
datos.loc[datos['YrSold']<=2008, "Crisis"] = "SI"
datos.loc[~(datos['YrSold']<=2008), "Crisis"] = "NO"

# %%
datos["Crisis"].value_counts()
# Out:
# Crisis
# SI    947
# NO    513
# Name: count, dtype: int64

# %% [markdown]
# Otra manera

# %%
datos["Crisis2"] = datos['YrSold']>2008
datos["Crisis2"]
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456     True
# 1457     True
# 1458     True
# 1459    False
# Name: Crisis2, Length: 1460, dtype: bool

# %%
datos["Crisis2"] = datos["Crisis2"].astype("category")
datos["Crisis2"] = datos["Crisis2"].cat.rename_categories({True: "NO", False: "SI"})
datos["Crisis2"]
# Out:
# 0       SI
# 1       SI
# 2       SI
# 3       SI
# 4       SI
#         ..
# 1455    SI
# 1456    NO
# 1457    NO
# 1458    NO
# 1459    SI
# Name: Crisis2, Length: 1460, dtype: category
# Categories (2, object): ['SI', 'NO']

# %% [markdown]
# # 6. Comprobar que se ha realizado correctamente.

# %%
#datos['Crisis'].value_counts()
datos['Crisis2'].value_counts()
# Out:
# Crisis2
# SI    947
# NO    513
# Name: count, dtype: int64

# %% [markdown]
# # 7. Crear un nuevo grupo de datos con las 10 casas más caras, en función de la variable “SalePrice”.

# %%
# Una orden
CasasCaras=datos.sort_values(['SalePrice'],ascending=False).head(n=10)
# Dos pasos
CasasCaras   = datos.sort_values(['SalePrice'], ascending = False)
CasasCaras10 = CasasCaras.head(10)

# %% [markdown]
# # 8. Determinar la calle en la que se encuentra la casa más cara.
# Consulta Cruzada

# %%
datos['SalePrice'].max()
# Out:
# 755000

# %%
datos['SalePrice']==datos['SalePrice'].max()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Name: SalePrice, Length: 1460, dtype: bool

# %%
callecara = datos['Street'][datos['SalePrice']==datos['SalePrice'].max()]
type(callecara)
# Out:
# pandas.core.series.Series

# %%
callebarata = datos['Street'][datos['SalePrice']==datos['SalePrice'].min()]
callebarata.values[0]
# Out:
# 'Pave'

# %%
calle_cara = datos[datos["SalePrice"] == datos["SalePrice"].max()]["Street"].values[0]
calle_barata = datos[datos["SalePrice"] == datos["SalePrice"].min()]["Street"].values[0]

# %%
calle_cara, calle_barata
# Out:
# ('Pave', 'Pave')

# %%
calle_cara = datos[datos["SalePrice"] == datos["SalePrice"].max()]["Street"].to_list()[0]
calle_barata = datos[datos["SalePrice"] == datos["SalePrice"].min()]["Street"].to_list()[0]

# %% [markdown]
# # 9. Crear una variable llamada “Reforma” y que muestre los años que pasaron entre la última  reforma y la venta (YrSold-YearRemodAdd).

# %%
datos['Reforma'] = datos['YrSold'] - datos['YearRemodAdd']

# %% [markdown]
# # 11. Guardar los datos.

# %%
datos.to_csv('ejercicios.csv')
