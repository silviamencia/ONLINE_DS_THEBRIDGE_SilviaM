# %% [markdown]
# # Modificaciones Avanzadas

# %%
import os
import pandas as pd
#import seaborn as sns
#import matplotlib.pyplot as plt

# %% [markdown]
# ## Carga de datos
# ---

# %%
df = pd.read_csv("/content/sample_data/data2.csv", sep="|", encoding="UTF-8")

# %%
df
# Out:
#        Unnamed: 0                 Catastro    ReferenciaCP  IdCliente  \
# 0          106640  087 2000501120UN02UN0UN  087 2000501120    6105422
# 1          205094  033 2006900750UN040B0UN  033 2006900750    6125687
# 2           21253  008 0105902010UN060C0UN  008 0105902010    6098841
# 3          149999  002 4802008896UN040C0UN  002 4802008896    6115427
# 4           58564  010 2007902403UN03CN0UN  010 2007902403    6103115
# ...           ...                      ...             ...        ...
# 13580      191276  005 4804400046UNPBUN001  005 4804400046      75816
# 13581      106294  005 0103601575UN020C0UN  005 0103601575    6109233
# 13582      214734  001 2004501209UNUNUNPOR  001 2004501209    2239094
# 13583      175766  001 4802009095UN050C0UN  001 4802009095    6119594
# 13584      122530  011 3120101590UN070C0UN  011 3120101590    6111352
#
#       Producto       Fecha        TipoProducto          AltaCliente
# 0          N01  2020-06-03  Servicio principal  2020-02-16 00:00:00
# 1          N01  2020-05-03  Servicio sin cuota  2020-03-19 00:00:00
# 2          N06  2020-03-03  Servicio principal  2020-01-11 00:00:00
# 3          N06  2020-05-03  Servicio principal  2020-02-26 00:00:00
# 4          N04  2020-05-03  Servicio principal  2020-01-25 00:00:00
# ...        ...         ...                 ...                  ...
# 13580      N06  2020-04-03  Servicio principal  2020-03-14 00:00:00
# 13581      N01  2020-03-03  Servicio sin cuota  2020-02-06 00:00:00
# 13582      N06  2020-04-03  Servicio principal  2020-03-24 00:00:00
# 13583      N01  2020-06-03  Servicio principal  2020-03-07 00:00:00
# 13584      N06  2020-06-03  Servicio principal  2020-02-16 00:00:00
#
# [13585 rows x 8 columns]

# %%
#Otra forma más elegante de cargar los datos...
import os

# Cambiar por carpeta donde se encuentren los datos
data_dir = '/content/sample_data/'

path = os.path.join(data_dir, 'data2.csv')
try:
    df = pd.read_csv(path, sep="|")  # para cargar csv tabulados, usar sep="\t"
except Exception as e:
    print(e)

# %% [markdown]
# ### Corregimos los errores
# Si hay errores, comprobamos los siguiente:
# * Caracter separador.
# * Caracter decimal.
# * Codificación.

# %%
df.head()
# Out:
#    Unnamed: 0                 Catastro    ReferenciaCP  IdCliente Producto  \
# 0      106640  087 2000501120UN02UN0UN  087 2000501120    6105422      N01
# 1      205094  033 2006900750UN040B0UN  033 2006900750    6125687      N01
# 2       21253  008 0105902010UN060C0UN  008 0105902010    6098841      N06
# 3      149999  002 4802008896UN040C0UN  002 4802008896    6115427      N06
# 4       58564  010 2007902403UN03CN0UN  010 2007902403    6103115      N04
#
#         Fecha        TipoProducto          AltaCliente
# 0  2020-06-03  Servicio principal  2020-02-16 00:00:00
# 1  2020-05-03  Servicio sin cuota  2020-03-19 00:00:00
# 2  2020-03-03  Servicio principal  2020-01-11 00:00:00
# 3  2020-05-03  Servicio principal  2020-02-26 00:00:00
# 4  2020-05-03  Servicio principal  2020-01-25 00:00:00

# %% [markdown]
# ### Exploración inicial

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13585 entries, 0 to 13584
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    13585 non-null  int64
#  1   Catastro      13573 non-null  object
#  2   ReferenciaCP  13585 non-null  object
#  3   IdCliente     13585 non-null  int64
#  4   Producto      13585 non-null  object
#  5   Fecha         13585 non-null  object
#  6   TipoProducto  13585 non-null  object
#  7   AltaCliente   13585 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 849.2+ KB

# %% [markdown]
# ### Corregimos los tipos de datos
# Modificamos la carga de datos definiendo:
# * Columnas que utilizar.
# * Columnas que parsear a fecha.
# * Tipo del resto de columnas.
# * Eliminar columna 0

# %%
df['Catastro'] = df['Catastro'].astype('string')
df['IdCliente'] = df['IdCliente'].astype('string')
df['Producto'] = df['Producto'].astype('category')
df['TipoProducto'] = df['TipoProducto'].astype('category')
df = df.drop(columns="Unnamed: 0")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13585 entries, 0 to 13584
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Catastro      13573 non-null  string
#  1   ReferenciaCP  13585 non-null  object
#  2   IdCliente     13585 non-null  string
#  3   Producto      13585 non-null  category
#  4   Fecha         13585 non-null  object
#  5   TipoProducto  13585 non-null  category
#  6   AltaCliente   13585 non-null  object
# dtypes: category(2), object(3), string(2)
# memory usage: 557.6+ KB

# %% [markdown]
# ### Corregimos el resto de errores
# Si alguna columna no se ha modificado su tipo, puede ser porque contenga errores. Modificamos el tipo indicando que se ignoren los errores.

# %%
df['Fecha']
# Out:
# 0        2020-06-03
# 1        2020-05-03
# 2        2020-03-03
# 3        2020-05-03
# 4        2020-05-03
#             ...
# 13580    2020-04-03
# 13581    2020-03-03
# 13582    2020-04-03
# 13583    2020-06-03
# 13584    2020-06-03
# Name: Fecha, Length: 13585, dtype: object

# %%
df['Fecha'] = pd.to_datetime(df['Fecha'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13585 entries, 0 to 13584
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Catastro      13573 non-null  string
#  1   ReferenciaCP  13585 non-null  object
#  2   IdCliente     13585 non-null  string
#  3   Producto      13585 non-null  category
#  4   Fecha         13585 non-null  datetime64[ns]
#  5   TipoProducto  13585 non-null  category
#  6   AltaCliente   13585 non-null  object
# dtypes: category(2), datetime64[ns](1), object(2), string(2)
# memory usage: 557.6+ KB

# %%
# df = df.drop('Unnamed: 0', axis=1)

# %% [markdown]
# ## Exploración y modificación
# ---

# %%
df.head()
# Out:
#                   Catastro    ReferenciaCP IdCliente Producto      Fecha  \
# 0  087 2000501120UN02UN0UN  087 2000501120   6105422      N01 2020-06-03
# 1  033 2006900750UN040B0UN  033 2006900750   6125687      N01 2020-05-03
# 2  008 0105902010UN060C0UN  008 0105902010   6098841      N06 2020-03-03
# 3  002 4802008896UN040C0UN  002 4802008896   6115427      N06 2020-05-03
# 4  010 2007902403UN03CN0UN  010 2007902403   6103115      N04 2020-05-03
#
#          TipoProducto          AltaCliente
# 0  Servicio principal  2020-02-16 00:00:00
# 1  Servicio sin cuota  2020-03-19 00:00:00
# 2  Servicio principal  2020-01-11 00:00:00
# 3  Servicio principal  2020-02-26 00:00:00
# 4  Servicio principal  2020-01-25 00:00:00

# %%
# Renombramos columnas
# Catastro renombrar a CatastroMax
# ReferenciaCP renombrar a CPReferenciado
df = df.rename(columns={'Catastro':'CatastroMax','ReferenciaCP':'CPReferenciado'})

# %%
df
# Out:
#                    CatastroMax  CPReferenciado IdCliente Producto      Fecha  \
# 0      087 2000501120UN02UN0UN  087 2000501120   6105422      N01 2020-06-03
# 1      033 2006900750UN040B0UN  033 2006900750   6125687      N01 2020-05-03
# 2      008 0105902010UN060C0UN  008 0105902010   6098841      N06 2020-03-03
# 3      002 4802008896UN040C0UN  002 4802008896   6115427      N06 2020-05-03
# 4      010 2007902403UN03CN0UN  010 2007902403   6103115      N04 2020-05-03
# ...                        ...             ...       ...      ...        ...
# 13580  005 4804400046UNPBUN001  005 4804400046     75816      N06 2020-04-03
# 13581  005 0103601575UN020C0UN  005 0103601575   6109233      N01 2020-03-03
# 13582  001 2004501209UNUNUNPOR  001 2004501209   2239094      N06 2020-04-03
# 13583  001 4802009095UN050C0UN  001 4802009095   6119594      N01 2020-06-03
# 13584  011 3120101590UN070C0UN  011 3120101590   6111352      N06 2020-06-03
#
#              TipoProducto          AltaCliente
# 0      Servicio principal  2020-02-16 00:00:00
# 1      Servicio sin cuota  2020-03-19 00:00:00
# 2      Servicio principal  2020-01-11 00:00:00
# 3      Servicio principal  2020-02-26 00:00:00
# 4      Servicio principal  2020-01-25 00:00:00
# ...                   ...                  ...
# 13580  Servicio principal  2020-03-14 00:00:00
# 13581  Servicio sin cuota  2020-02-06 00:00:00
# 13582  Servicio principal  2020-03-24 00:00:00
# 13583  Servicio principal  2020-03-07 00:00:00
# 13584  Servicio principal  2020-02-16 00:00:00
#
# [13585 rows x 7 columns]

# %%
# Generar variables dummies
df_dummies_Producto = pd.get_dummies(df, columns=['Producto'])
df_dummies_Producto.head()
# df_dummies_Producto["Producto"] =df["Producto"]
# Out:
#                CatastroMax  CPReferenciado IdCliente      Fecha  \
# 0  087 2000501120UN02UN0UN  087 2000501120   6105422 2020-06-03
# 1  033 2006900750UN040B0UN  033 2006900750   6125687 2020-05-03
# 2  008 0105902010UN060C0UN  008 0105902010   6098841 2020-03-03
# 3  002 4802008896UN040C0UN  002 4802008896   6115427 2020-05-03
# 4  010 2007902403UN03CN0UN  010 2007902403   6103115 2020-05-03
#
#          TipoProducto          AltaCliente  Producto_N01  Producto_N03  \
# 0  Servicio principal  2020-02-16 00:00:00          True         False
# 1  Servicio sin cuota  2020-03-19 00:00:00          True         False
# 2  Servicio principal  2020-01-11 00:00:00         False         False
# 3  Servicio principal  2020-02-26 00:00:00         False         False
# 4  Servicio principal  2020-01-25 00:00:00         False         False
#
#    Producto_N04  Producto_N06
# 0         False         False
# 1         False         False
# 2         False          True
# 3         False          True
# 4          True         False

# %%
df_dummies_Producto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13585 entries, 0 to 13584
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CatastroMax     13573 non-null  string
#  1   CPReferenciado  13585 non-null  object
#  2   IdCliente       13585 non-null  string
#  3   Fecha           13585 non-null  datetime64[ns]
#  4   TipoProducto    13585 non-null  category
#  5   AltaCliente     13585 non-null  object
#  6   Producto_N01    13585 non-null  bool
#  7   Producto_N03    13585 non-null  bool
#  8   Producto_N04    13585 non-null  bool
#  9   Producto_N06    13585 non-null  bool
# dtypes: bool(4), category(1), datetime64[ns](1), object(2), string(2)
# memory usage: 597.2+ KB

# %%
df_dummies_Producto["TipoProducto"] = df_dummies_Producto["TipoProducto"] == "Servicio principal"

# %%
df_dummies_Producto["TipoProducto"].value_counts()
# Out:
# TipoProducto
# True     11010
# False     2575
# Name: count, dtype: int64

# %%
# Voy a generar una columna con supuestos datos de facturación a partir de datos aleatorios con media 1000 y varianza 250
df_dummies_Producto['Facturacion'] = np.random.normal(1000, 250, df_dummies_Producto.shape[0])
any(df_dummies_Producto['Facturacion'] < 0)

# %%
df_dummies_Producto.head()
# Out:
#                CatastroMax  CPReferenciado IdCliente      Fecha  TipoProducto  \
# 0  087 2000501120UN02UN0UN  087 2000501120   6105422 2020-06-03          True
# 1  033 2006900750UN040B0UN  033 2006900750   6125687 2020-05-03         False
# 2  008 0105902010UN060C0UN  008 0105902010   6098841 2020-03-03          True
# 3  002 4802008896UN040C0UN  002 4802008896   6115427 2020-05-03          True
# 4  010 2007902403UN03CN0UN  010 2007902403   6103115 2020-05-03          True
#
#            AltaCliente  Producto_N01  Producto_N03  Producto_N04  \
# 0  2020-02-16 00:00:00          True         False         False
# 1  2020-03-19 00:00:00          True         False         False
# 2  2020-01-11 00:00:00         False         False         False
# 3  2020-02-26 00:00:00         False         False         False
# 4  2020-01-25 00:00:00         False         False          True
#
#    Producto_N06  Facturacion
# 0         False  198426.2150
# 1         False  199084.8275
# 2          True  198212.3325
# 3          True  198751.3775
# 4         False  198351.2375

# %%
df_dummies_Producto_num = df_dummies_Producto.select_dtypes(["number", "datetime"])
df_dummies_Producto_num
# Out:
#            Fecha  Facturacion
# 0     2020-06-03  198426.2150
# 1     2020-05-03  199084.8275
# 2     2020-03-03  198212.3325
# 3     2020-05-03  198751.3775
# 4     2020-05-03  198351.2375
# ...          ...          ...
# 13580 2020-04-03    2464.0200
# 13581 2020-03-03  198550.0725
# 13582 2020-04-03   72770.5550
# 13583 2020-06-03  198886.8050
# 13584 2020-06-03  198618.9400
#
# [13585 rows x 2 columns]

# %%
df_dummies_Producto_num['IdCliente'] = df_dummies_Producto['IdCliente']
df_productos_cliente = df_dummies_Producto_num.groupby(['IdCliente', 'Fecha']).sum().reset_index()
df_productos_cliente.head()
# Out:
#   IdCliente      Fecha  Facturacion
# 0    100787 2020-05-03    3275.5775
# 1    101376 2020-05-03    3294.7200
# 2   1018161 2020-05-03   33090.2325
# 3    103899 2020-05-03    3376.7175
# 4    103899 2020-06-03    3376.7175

# %% [markdown]
# ## Consultas a dataframes
# ---

# %% [markdown]
# ### Contrataciones del mes de marzo

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13585 entries, 0 to 13584
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CatastroMax     13573 non-null  string
#  1   CPReferenciado  13585 non-null  object
#  2   IdCliente       13585 non-null  string
#  3   Producto        13585 non-null  category
#  4   Fecha           13585 non-null  datetime64[ns]
#  5   TipoProducto    13585 non-null  category
#  6   AltaCliente     13585 non-null  object
# dtypes: category(2), datetime64[ns](1), object(2), string(2)
# memory usage: 557.6+ KB

# %%
df["Fecha"].dt.day == 3
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 13580    True
# 13581    True
# 13582    True
# 13583    True
# 13584    True
# Name: Fecha, Length: 13585, dtype: bool

# %%
df.query('Fecha.dt.day == 3')
# Out:
#                    CatastroMax  CPReferenciado IdCliente Producto      Fecha  \
# 0      087 2000501120UN02UN0UN  087 2000501120   6105422      N01 2020-06-03
# 1      033 2006900750UN040B0UN  033 2006900750   6125687      N01 2020-05-03
# 2      008 0105902010UN060C0UN  008 0105902010   6098841      N06 2020-03-03
# 3      002 4802008896UN040C0UN  002 4802008896   6115427      N06 2020-05-03
# 4      010 2007902403UN03CN0UN  010 2007902403   6103115      N04 2020-05-03
# ...                        ...             ...       ...      ...        ...
# 13580  005 4804400046UNPBUN001  005 4804400046     75816      N06 2020-04-03
# 13581  005 0103601575UN020C0UN  005 0103601575   6109233      N01 2020-03-03
# 13582  001 2004501209UNUNUNPOR  001 2004501209   2239094      N06 2020-04-03
# 13583  001 4802009095UN050C0UN  001 4802009095   6119594      N01 2020-06-03
# 13584  011 3120101590UN070C0UN  011 3120101590   6111352      N06 2020-06-03
#
#              TipoProducto          AltaCliente
# 0      Servicio principal  2020-02-16 00:00:00
# 1      Servicio sin cuota  2020-03-19 00:00:00
# 2      Servicio principal  2020-01-11 00:00:00
# 3      Servicio principal  2020-02-26 00:00:00
# 4      Servicio principal  2020-01-25 00:00:00
# ...                   ...                  ...
# 13580  Servicio principal  2020-03-14 00:00:00
# 13581  Servicio sin cuota  2020-02-06 00:00:00
# 13582  Servicio principal  2020-03-24 00:00:00
# 13583  Servicio principal  2020-03-07 00:00:00
# 13584  Servicio principal  2020-02-16 00:00:00
#
# [13585 rows x 7 columns]

# %%
df.query('AltaCliente.dt.day <= 10')
#No funciona pq AltaCliente no es de tipo datetime
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-7f9b0c9ca445> in <cell line: 1>()
# ----> 1 df.query('AltaCliente.dt.day <= 10')
#       2 #No funciona pq AltaCliente no es de tipo datetime
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    4821         kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822         kwargs["target"] = None
# -> 4823         res = self.eval(expr, **kwargs)
#    4824
#    4825         try:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    4947         kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
#    4948
# -> 4949         return _eval(expr, inplace=inplace, **kwargs)
#    4950
#    4951     def select_dtypes(self, include=None, exclude=None) -> Self:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     334         )
#     335
# --> 336         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     337
#     338         if engine == "numexpr" and (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expr.py in __init__(self, expr, engine, parser, env, level)
#     807         self.parser = parser
#     808         self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 809         self.terms = self.parse()
#     810
#     811     @property
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expr.py in parse(self)
#     826         Parse an expression.
#     827         """
# --> 828         return self._visitor.visit(self.expr)
#     829
#     830     @property
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     410         method = f"visit_{type(node).__name__}"
#     411         visitor = getattr(self, method)
# --> 412         return visitor(node, **kwargs)
#     413
#     414     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expr.py in visit_Module(self, node, **kwargs)
#     416             raise SyntaxError("only a single expression is allowed")
#     417         expr = node.body[0]
# --> 418         return self.visit(expr, **kwargs)
#     419
#     420     def visit_Expr(self, node, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     410         method = f"visit_{type(node).__name__}"
#     411         visitor = getattr(self, method)
# --> 412         return visitor(node, **kwargs)
#     413
#     414     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expr.py in visit_Expr(self, node, **kwargs)
#     419
#     420     def visit_Expr(self, node, **kwargs):
# --> 421         return self.visit(node.value, **kwargs)
#     422
#     423     def _rewrite_membership_op(self, node, left, right):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     410         method = f"visit_{type(node).__name__}"
#     411         visitor = getattr(self, method)
# --> 412         return visitor(node, **kwargs)
#     413
#     414     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expr.py in visit_Compare(self, node, **kwargs)
#     717             op = self.translate_In(ops[0])
#     718             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 719             return self.visit(binop)
#     720
#     721         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     410         method = f"visit_{type(node).__name__}"
#     411         visitor = getattr(self, method)
# --> 412         return visitor(node, **kwargs)
#     413
#     414     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expr.py in visit_BinOp(self, node, **kwargs)
#     530
#     531     def visit_BinOp(self, node, **kwargs):
# --> 532         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     533         left, right = self._maybe_downcast_constants(left, right)
#     534         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     450     def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     451         if left is None:
# --> 452             left = self.visit(node.left, side="left")
#     453         if right is None:
#     454             right = self.visit(node.right, side="right")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     410         method = f"visit_{type(node).__name__}"
#     411         visitor = getattr(self, method)
# --> 412         return visitor(node, **kwargs)
#     413
#     414     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expr.py in visit_Attribute(self, node, **kwargs)
#     642         if isinstance(ctx, ast.Load):
#     643             # resolve the value
# --> 644             resolved = self.visit(value).value
#     645             try:
#     646                 v = getattr(resolved, attr)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     410         method = f"visit_{type(node).__name__}"
#     411         visitor = getattr(self, method)
# --> 412         return visitor(node, **kwargs)
#     413
#     414     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expr.py in visit_Attribute(self, node, **kwargs)
#     644             resolved = self.visit(value).value
#     645             try:
# --> 646                 v = getattr(resolved, attr)
#     647                 name = self.env.add_tmp(v)
#     648                 return self.term_type(name, self.env)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
#     226         # https://www.pydanny.com/cached-property.html
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/accessors.py in __new__(cls, data)
#     641             return PeriodProperties(data, orig)
#     642
# --> 643         raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
df['AltaCliente'] = pd.to_datetime(df['AltaCliente'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13585 entries, 0 to 13584
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CatastroMax     13573 non-null  string
#  1   CPReferenciado  13585 non-null  object
#  2   IdCliente       13585 non-null  string
#  3   Producto        13585 non-null  category
#  4   Fecha           13585 non-null  datetime64[ns]
#  5   TipoProducto    13585 non-null  category
#  6   AltaCliente     13585 non-null  datetime64[ns]
# dtypes: category(2), datetime64[ns](2), object(1), string(2)
# memory usage: 557.6+ KB

# %%
df.query('AltaCliente.dt.day <= 10')
# Out:
#                    CatastroMax  CPReferenciado IdCliente Producto      Fecha  \
# 5      003 2090200600UN010C0UN  003 2090200600   6118145      N06 2020-05-03
# 8      027 0100202420UN020B0UN  027 0100202420   6097637      N04 2020-04-03
# 13     016 0819600232UNLOUN001  016 0819600232   6106541      N01 2020-06-03
# 25     007 4802003050UN04IZ0UN  007 4802003050   6138507      N06 2020-05-03
# 27     003 4801500208UN01IZ0UN  003 4801500208   6106500      N01 2020-04-03
# ...                        ...             ...       ...      ...        ...
# 13570  003 2008001350UN040H0UN  003 2008001350   6103683      N01 2020-03-03
# 13577  004 4890200004UN020E0UN  004 4890200004   6106187      N04 2020-04-03
# 13578  008 2608400309UN040A0UN  008 2608400309   6101386      N06 2020-03-03
# 13581  005 0103601575UN020C0UN  005 0103601575   6109233      N01 2020-03-03
# 13583  001 4802009095UN050C0UN  001 4802009095   6119594      N01 2020-06-03
#
#              TipoProducto AltaCliente
# 5      Servicio principal  2020-03-01
# 8      Servicio principal  2020-01-09
# 13     Servicio principal  2020-02-02
# 25     Servicio principal  2020-05-02
# 27     Servicio sin cuota  2020-02-01
# ...                   ...         ...
# 13570  Servicio principal  2020-02-01
# 13577  Servicio principal  2020-02-06
# 13578  Servicio principal  2020-02-07
# 13581  Servicio sin cuota  2020-02-06
# 13583  Servicio principal  2020-03-07
#
# [4146 rows x 7 columns]

# %%
df['IdCliente'] = df['IdCliente'].astype('int')

# %%
df.query('AltaCliente.dt.day <= 10 or IdCliente<100000')
# Out:
#                    CatastroMax  CPReferenciado  IdCliente Producto      Fecha  \
# 5      003 2090200600UN010C0UN  003 2090200600    6118145      N06 2020-05-03
# 8      027 0100202420UN020B0UN  027 0100202420    6097637      N04 2020-04-03
# 13     016 0819600232UNLOUN001  016 0819600232    6106541      N01 2020-06-03
# 25     007 4802003050UN04IZ0UN  007 4802003050    6138507      N06 2020-05-03
# 27     003 4801500208UN01IZ0UN  003 4801500208    6106500      N01 2020-04-03
# ...                        ...             ...        ...      ...        ...
# 13577  004 4890200004UN020E0UN  004 4890200004    6106187      N04 2020-04-03
# 13578  008 2608400309UN040A0UN  008 2608400309    6101386      N06 2020-03-03
# 13580  005 4804400046UNPBUN001  005 4804400046      75816      N06 2020-04-03
# 13581  005 0103601575UN020C0UN  005 0103601575    6109233      N01 2020-03-03
# 13583  001 4802009095UN050C0UN  001 4802009095    6119594      N01 2020-06-03
#
#              TipoProducto AltaCliente
# 5      Servicio principal  2020-03-01
# 8      Servicio principal  2020-01-09
# 13     Servicio principal  2020-02-02
# 25     Servicio principal  2020-05-02
# 27     Servicio sin cuota  2020-02-01
# ...                   ...         ...
# 13577  Servicio principal  2020-02-06
# 13578  Servicio principal  2020-02-07
# 13580  Servicio principal  2020-03-14
# 13581  Servicio sin cuota  2020-02-06
# 13583  Servicio principal  2020-03-07
#
# [4321 rows x 7 columns]

# %% [markdown]
# ### Consultas más complejas

# %%
producto = 'N01'
df.query('AltaCliente.dt.day <= 10 and Producto == @producto')
# Out:
#                    CatastroMax  CPReferenciado  IdCliente Producto      Fecha  \
# 13     016 0819600232UNLOUN001  016 0819600232    6106541      N01 2020-06-03
# 27     003 4801500208UN01IZ0UN  003 4801500208    6106500      N01 2020-04-03
# 34     051 4802004630UN04IZ0UN  051 4802004630    6119105      N01 2020-05-03
# 44     002 2001901250UN01UN0UN  002 2001901250    6115892      N01 2020-04-03
# 53     167 0818000511E101UN003  167 0818000511    6116767      N01 2020-03-03
# ...                        ...             ...        ...      ...        ...
# 13542  014 0105904530UN05DR0UN  014 0105904530    6109525      N01 2020-04-03
# 13544  009 4808200107UN010A0UN  009 4808200107    6105932      N01 2020-06-03
# 13570  003 2008001350UN040H0UN  003 2008001350    6103683      N01 2020-03-03
# 13581  005 0103601575UN020C0UN  005 0103601575    6109233      N01 2020-03-03
# 13583  001 4802009095UN050C0UN  001 4802009095    6119594      N01 2020-06-03
#
#              TipoProducto AltaCliente
# 13     Servicio principal  2020-02-02
# 27     Servicio sin cuota  2020-02-01
# 34     Servicio principal  2020-03-07
# 44     Servicio principal  2020-03-08
# 53     Servicio principal  2020-03-01
# ...                   ...         ...
# 13542  Servicio sin cuota  2020-02-07
# 13544  Servicio principal  2020-02-01
# 13570  Servicio principal  2020-02-01
# 13581  Servicio sin cuota  2020-02-06
# 13583  Servicio principal  2020-03-07
#
# [1279 rows x 7 columns]

# %%
producto = 'N01'
tipoprod = 'Servicio sin cuota'
df.query('AltaCliente.dt.day <= 10 and (Producto == @producto or TipoProducto == @tipoprod)')
# Out:
#                    CatastroMax  CPReferenciado  IdCliente Producto      Fecha  \
# 13     016 0819600232UNLOUN001  016 0819600232    6106541      N01 2020-06-03
# 27     003 4801500208UN01IZ0UN  003 4801500208    6106500      N01 2020-04-03
# 33     014B2512000200UN03UN004  014B2512000200    6110921      N06 2020-05-03
# 34     051 4802004630UN04IZ0UN  051 4802004630    6119105      N01 2020-05-03
# 44     002 2001901250UN01UN0UN  002 2001901250    6115892      N01 2020-04-03
# ...                        ...             ...        ...      ...        ...
# 13554  196 0801901015UN04UN001  196 0801901015    6098519      N06 2020-04-03
# 13558  421 0801900368UN050B0UN  421 0801900368    6139655      N06 2020-06-03
# 13570  003 2008001350UN040H0UN  003 2008001350    6103683      N01 2020-03-03
# 13581  005 0103601575UN020C0UN  005 0103601575    6109233      N01 2020-03-03
# 13583  001 4802009095UN050C0UN  001 4802009095    6119594      N01 2020-06-03
#
#              TipoProducto AltaCliente
# 13     Servicio principal  2020-02-02
# 27     Servicio sin cuota  2020-02-01
# 33     Servicio sin cuota  2020-02-10
# 34     Servicio principal  2020-03-07
# 44     Servicio principal  2020-03-08
# ...                   ...         ...
# 13554  Servicio sin cuota  2020-01-10
# 13558  Servicio sin cuota  2020-05-07
# 13570  Servicio principal  2020-02-01
# 13581  Servicio sin cuota  2020-02-06
# 13583  Servicio principal  2020-03-07
#
# [1598 rows x 7 columns]

# %%
# Extraemos del Catastro el código de área
# Para ello eliminamos primero todos los espacios y posteriormente extraemos el texto de las posiciones 3 a 4
df['Provincia'] = df['CatastroMax'].str.replace(" ","")
df['Provincia'] = df['Provincia'].str.slice(3,5)
df.tail()
# Out:
#                    CatastroMax  CPReferenciado  IdCliente Producto      Fecha  \
# 13580  005 4804400046UNPBUN001  005 4804400046      75816      N06 2020-04-03
# 13581  005 0103601575UN020C0UN  005 0103601575    6109233      N01 2020-03-03
# 13582  001 2004501209UNUNUNPOR  001 2004501209    2239094      N06 2020-04-03
# 13583  001 4802009095UN050C0UN  001 4802009095    6119594      N01 2020-06-03
# 13584  011 3120101590UN070C0UN  011 3120101590    6111352      N06 2020-06-03
#
#              TipoProducto AltaCliente Provincia
# 13580  Servicio principal  2020-03-14        48
# 13581  Servicio sin cuota  2020-02-06        01
# 13582  Servicio principal  2020-03-24        20
# 13583  Servicio principal  2020-03-07        48
# 13584  Servicio principal  2020-02-16        31

# %% [markdown]
# ### Clientes cuya antiguedad sea anterior al MES DE MARZO

# %%
df.query('AltaCliente.dt.month < 3')
# Out:
#                    CatastroMax  CPReferenciado  IdCliente Producto      Fecha  \
# 0      087 2000501120UN02UN0UN  087 2000501120    6105422      N01 2020-06-03
# 2      008 0105902010UN060C0UN  008 0105902010    6098841      N06 2020-03-03
# 3      002 4802008896UN040C0UN  002 4802008896    6115427      N06 2020-05-03
# 4      010 2007902403UN03CN0UN  010 2007902403    6103115      N04 2020-05-03
# 6      078 4802004120UN07IZ0UN  078 4802004120    6100111      N04 2020-05-03
# ...                        ...             ...        ...      ...        ...
# 13577  004 4890200004UN020E0UN  004 4890200004    6106187      N04 2020-04-03
# 13578  008 2608400309UN040A0UN  008 2608400309    6101386      N06 2020-03-03
# 13579  012 0105902035UN04DR0UN  012 0105902035     486645      N04 2020-04-03
# 13581  005 0103601575UN020C0UN  005 0103601575    6109233      N01 2020-03-03
# 13584  011 3120101590UN070C0UN  011 3120101590    6111352      N06 2020-06-03
#
#              TipoProducto AltaCliente Provincia
# 0      Servicio principal  2020-02-16        20
# 2      Servicio principal  2020-01-11        01
# 3      Servicio principal  2020-02-26        48
# 4      Servicio principal  2020-01-25        20
# 6      Servicio principal  2020-01-18        48
# ...                   ...         ...       ...
# 13577  Servicio principal  2020-02-06        48
# 13578  Servicio principal  2020-02-07        26
# 13579  Servicio principal  2020-01-20        01
# 13581  Servicio sin cuota  2020-02-06        01
# 13584  Servicio principal  2020-02-16        31
#
# [8463 rows x 8 columns]

# %% [markdown]
# ### Facturación media del mes de abril del 2020

# %%
df ['Facturacion'] = df['IdCliente'].astype('int') / 40 * 1.3

# %% [markdown]
# ### Facturación maxima y minima para Producto N06 de los clientes que no pertenezcan a Bizkaia

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13585 entries, 0 to 13584
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CatastroMax     13573 non-null  string
#  1   CPReferenciado  13585 non-null  object
#  2   IdCliente       13585 non-null  int64
#  3   Producto        13585 non-null  category
#  4   Fecha           13585 non-null  datetime64[ns]
#  5   TipoProducto    13585 non-null  category
#  6   AltaCliente     13585 non-null  datetime64[ns]
#  7   Provincia       13573 non-null  string
#  8   Facturacion     13585 non-null  float64
# dtypes: category(2), datetime64[ns](2), float64(1), int64(1), object(1), string(2)
# memory usage: 769.9+ KB

# %%
df['Provincia'] = df['Provincia'].astype('string')

# %%
df2 = df.query('Provincia !="48"')

# %%
df2
# Out:
#                    CatastroMax  CPReferenciado  IdCliente Producto      Fecha  \
# 0      087 2000501120UN02UN0UN  087 2000501120    6105422      N01 2020-06-03
# 1      033 2006900750UN040B0UN  033 2006900750    6125687      N01 2020-05-03
# 2      008 0105902010UN060C0UN  008 0105902010    6098841      N06 2020-03-03
# 4      010 2007902403UN03CN0UN  010 2007902403    6103115      N04 2020-05-03
# 5      003 2090200600UN010C0UN  003 2090200600    6118145      N06 2020-05-03
# ...                        ...             ...        ...      ...        ...
# 13578  008 2608400309UN040A0UN  008 2608400309    6101386      N06 2020-03-03
# 13579  012 0105902035UN04DR0UN  012 0105902035     486645      N04 2020-04-03
# 13581  005 0103601575UN020C0UN  005 0103601575    6109233      N01 2020-03-03
# 13582  001 2004501209UNUNUNPOR  001 2004501209    2239094      N06 2020-04-03
# 13584  011 3120101590UN070C0UN  011 3120101590    6111352      N06 2020-06-03
#
#              TipoProducto AltaCliente Provincia  Facturacion
# 0      Servicio principal  2020-02-16        20  198426.2150
# 1      Servicio sin cuota  2020-03-19        20  199084.8275
# 2      Servicio principal  2020-01-11        01  198212.3325
# 4      Servicio principal  2020-01-25        20  198351.2375
# 5      Servicio principal  2020-03-01        20  198839.7125
# ...                   ...         ...       ...          ...
# 13578  Servicio principal  2020-02-07        26  198295.0450
# 13579  Servicio principal  2020-01-20        01   15815.9625
# 13581  Servicio sin cuota  2020-02-06        01  198550.0725
# 13582  Servicio principal  2020-03-24        20   72770.5550
# 13584  Servicio principal  2020-02-16        31  198618.9400
#
# [7783 rows x 9 columns]

# %%
df2["Facturacion"].max()
# Out:
# 199975.945

# %%
df2["Facturacion"].min()
# Out:
# 15.209999999999999
